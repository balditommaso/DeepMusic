# %%
# !pip install miditok
# Out:
# Collecting miditok
#   Using cached miditok-1.3.3-py3-none-any.whl (76 kB)
# Collecting miditoolkit>=0.1.16
#   Using cached miditoolkit-0.1.16-py3-none-any.whl (20 kB)
# Requirement already satisfied: tqdm in /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from miditok) (4.64.1)
# Requirement already satisfied: numpy>=1.19 in /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from miditok) (1.23.3)
# Requirement already satisfied: mido>=1.1.16 in /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from miditoolkit>=0.1.16->miditok) (1.2.10)
# Installing collected packages: miditoolkit, miditok
# Successfully installed miditok-1.3.3 miditoolkit-0.1.16

# %%
import os
import sys
import IPython
sys.path.insert(0, os.path.abspath('../Utils/'))
import midi_util

dir_path = "../midis"

# %% [markdown]
# ### Example of file

# %%
file = os.path.join(dir_path, os.listdir(dir_path)[0])
midi = midi_util.MidiUtils(file)
midi.play_midi()
# Out:
#                 <div id="midiPlayerDiv48435"></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer("#midiPlayerDiv48435");
#                                mp.base64Load("data:audio/midi;base64,...");
#                         });
#                 </script>

# %%
# !pip3 install miditok
# Out:
# Requirement already satisfied: miditok in /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages (1.3.3)
# Requirement already satisfied: tqdm in /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from miditok) (4.64.1)
# Requirement already satisfied: numpy>=1.19 in /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from miditok) (1.23.3)
# Requirement already satisfied: miditoolkit>=0.1.16 in /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from miditok) (0.1.16)
# Requirement already satisfied: mido>=1.1.16 in /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from miditoolkit>=0.1.16->miditok) (1.2.10)

# %%
from miditok import REMI, CPWord
from miditoolkit import MidiFile

# TODO: extract info and plot piano roll

# %%
class MidiVectorizer:
    
    def __init__(self, multi_note=False, pitch_range=None, nb_velocities=None, additional_tokens=None, pad=False, sos_eos=False, mask=False) -> None:
        if multi_note:
            self.tokenizer = CPWord(pitch_range=pitch_range, nb_velocities=nb_velocities, additional_tokens=additional_tokens, pad=pad, sos_eos=sos_eos, mask=mask)
        else:
            self.tokenizer = REMI(pitch_range=pitch_range, nb_velocities=nb_velocities, additional_tokens=additional_tokens, pad=pad, sos_eos=sos_eos, mask=mask)
    
    def encode(self, path):
        midi = MidiFile(path)
        return self.tokenizer.midi_to_tokens(midi)
    
    def decode(self, tokens):
        return self.tokenizer.tokens_to_midi(tokens)

# %%
pitch_range = range(21, 109)
nb_velocities = 32
additional_tokens = {'Chord': False, 'Rest': True, 'Tempo': False, 'Program': False, 'TimeSignature': False,
                     'rest_range': (2, 8),  # (half, 8 beats)
                     'nb_tempos': 64,  # nb of tempo bins
                     }  # (min, max)

vectorizer_remi = MidiVectorizer(pitch_range=pitch_range, nb_velocities=nb_velocities, additional_tokens=additional_tokens, pad=True, sos_eos=True)
vectorizer_cpword = MidiVectorizer(multi_note=True, pitch_range=pitch_range, nb_velocities=nb_velocities, additional_tokens=additional_tokens, pad=True, sos_eos=True)

file = os.path.join(dir_path, os.listdir(dir_path)[34])
midi = midi_util.MidiUtils(file)
print("Original:")
midi.play_midi()

# REMI
tokens_remi = vectorizer_remi.encode(file)
back_to_midi = vectorizer_remi.decode(tokens_remi)
back_to_midi.dump("../decode_example.mid")
midi = midi_util.MidiUtils("../decode_example.mid")
print("Decoded REMI:")
midi.play_midi()

# CPWord
tokens_cpword = vectorizer_cpword.encode(file)
back_to_midi = vectorizer_cpword.decode(tokens_cpword)
back_to_midi.dump("../decode_example.mid")
midi = midi_util.MidiUtils("../decode_example.mid")
print("Decoded CPWord:")
midi.play_midi()
# Out:
# Original:
#                 <div id="midiPlayerDiv283652"></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer("#midiPlayerDiv283652");
#                                mp.base64Load("data:audio/midi;base64,...");
#                         });
#                 </script>
# Decoded REMI:
#                 <div id="midiPlayerDiv318642"></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer("#midiPlayerDiv318642");
#                                mp.base64Load("data:audio/midi;base64,...");
#                         });
#                 </script>
# Decoded CPWord:
#                 <div id="midiPlayerDiv353621"></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer("#midiPlayerDiv353621");
#                                mp.base64Load("data:audio/midi;base64,...");
#                         });
#                 </script>

# %% [markdown]
# process all the data

# %%
def tokenize_directory(dir=None):
    base_dir = "../dataset/" + dir
    all_tokens = []
    fnames = os.listdir(base_dir)
    for fname in fnames:
        print(fname)
        tokens = vectorizer_remi.encode(os.path.join(base_dir, fname))
        all_tokens.append(tokens)
    return all_tokens

training_tokens = tokenize_directory("training")
len(training_tokens)
# Out:
# Legnani, Luigi, Rondoletto scherzoso, Op.204, iq55D8Ex4Fo.mid
# Kötzschke, Hanns, Piano Sonata, BY8n7VRjhg4.mid
# Scriabin, Aleksandr, 2 Impromptus à la Mazur, Op.7, OiiLx4Xqv3Q.mid
# Medeiros, Anacleto de, Terna saudade, O7mM2_K2C40.mid
# Bohm, Carl, Addio a Napoli, Op.258, d2JR9yPwjMY.mid
# Graupner, Christoph, Partita in C major, GWV 805, Nj8h_0gJKB4.mid
# Mendelssohn, Felix, Clarinet Sonata in E-flat major, MWV Q 15, zhotPVqosa0.mid
# Bennett, William Sterndale, 3 Musical Sketches, Op.10, HjT2pciYq6M.mid
# Herz, Henri, Rêverie Nocturne, Op.194, WLb-b91Rchg.mid
# Medtner, Nikolay, 2 Elegies, Op.59, YybGvkz71Do.mid
# Rosenhain, Jacob, 4 Romances, Op.14, OGbJLgE1JF0.mid
# Nepomuceno, Alberto, Improviso, Op.27 No.2, Cc-HuzV5Omk.mid
# Pachman, Jason L., Fugue No.1 in C major, iK3GXWMHo08.mid
# Stahl, William C., Always Faithful, WRead8HeMNE.mid
# Villanueva, Felipe, Vals 'Amor', prkx-QcFXC4.mid
# Leybach, Ignace Xavier Joseph, Pensée de jeune fille, Op.17, -d69AQHyz4M.mid
# Bernard, Émile, Prélude et Fugue, Op.14, VrBHxZo5guY.mid
# Joplin, Scott, Silver Swan Rag, rFd9nXMkBK8.mid
# Liszt, Franz, La romanesca, S.252a, ZbeYcB7ME-Y.mid
# Masarnau, Santiago de, 3 Morceaux expressifs, Op.18, MdKPvWUF5gI.mid
# Bottazzo, Luigi, Diffusa est, hCMURbFKPa8.mid
# Kowalski, Henri, Menuet de Marie Lesczynska, Op.23, qdrDaPRolg4.mid
# Poulenc, Francis, Elegy, FP 175, WRfAU_RIG8Q.mid
# Tchaikovsky, Pyotr, Grand Sonata, Op.37, oU7cE6qDGxE.mid
# Warren, George William, The Song of the Robin, HiSsJRvX3RA.mid
# Bach, Carl Philipp Emanuel, Rondo in G major, H.271, 996yMEb6v_s.mid
# Marando, A., Nocturne No.1, Op.9, Nb3vj9zTHX0.mid
# Pearson, Kevin, What Shall I Do?, dtFdLbDmudk.mid
# Vargas, Guillaume, The Spirit of the Nile, IwsHfns7i2o.mid
# Melartin, Erkki, 3 Piano Pieces, Op.8, 18Tn9S1yssA.mid
# Moeran, Ernest John, 3 Piano Pieces, 6MGev767MEk.mid
# Handel, George Frideric, Capriccio in F major, HWV 481, xI7sSJAI78g.mid
# Scarlatti, Domenico, Keyboard Sonata in C minor, K.526, 5gSMdS_OHc0.mid
# Blumenfeld, Felix, Etude de Concert, Op.24, KhEWwK3peb4.mid
# Zhang, Shuwen, Etude No.14 in E-flat minor 'Cavatina', dlL4y5v1Vwc.mid
# Scharwenka, Xaver, Polonaise, Op.12, 4S3MfTBMuv4.mid
# Folwell, John C., Mountain Breezes, DK1-LMl6hGQ.mid
# Neustedt, Charles, Idylle No.1, Op.82, O6i3jKqCfM0.mid
# Purcell, Henry, Suite in F major, Z.669, JouTC_xWAJc.mid
# Schumann, Robert, Presto, H_K WoO 5,2, b_Hy63bZSY4.mid
# Schütt, Eduard, Pages intimes, Op.68, ba6zqd4gTQc.mid
# Clutsam, George Howard, Souvenir, eaKunw3chqw.mid
# Karpov, Mikhail, Nocturne, Op.2, rT9bbDK1cRE.mid
# Frey, E. H., Spanish Dance, 6QMZ-CCbgV0.mid
# Carbajo, Víctor, Mersenne XIII, 5NJ2AJp_E7Y.mid
# Agnew, Roy, Youthful Fancies, YIK8RatMELo.mid
# Kiel, Friedrich, 6 Walzer, Op.7, NrVabXoTzNE.mid
# Fabricius, Jacob, Nocturne in B-flat major, P_S-PN6oDlU.mid
# Kölling, Adolph, Valse gracieuse, Op.11, k0zzeL0QxLA.mid
# Johnson, Charles Leslie, Southern Beauties, JUVzbfkhhNs.mid
# Schumann, Robert, Papillons, Op.2, fGeKTOXhr74.mid
# Chaminade, Cécile, Piano Sonata, Op.21, L4IjloAwgd4.mid
# Carbajo, Víctor, 4 Young Improvisations, 1j3pyOBY1DI.mid
# Iversen, Niels Johannes Legarth, Piano Sonata No.3, Op.58, xGJxmCOPFVM.mid
# Junck, Christian, Piano Sonata No.5 in G major, 0rnJu1rlm90.mid
# Saint-Saëns, Camille, La cigale et la fourmi, SgL68lyIr7U.mid
# Arndt, Felix, Kakuda, iD8SLLbmC20.mid
# Ketterer, Eugène, Boute-en-train, Op.121, YaAIm2Ft8qc.mid
# Weber, Carl Maria von, Polacca brillante, Op.72, WkRrRedO6Ms.mid
# Lipski, Stanisław, 5 Morceaux, Op.8, lnyVRj-hPbU.mid
# Praeger, Ferdinand, Mazurka in B-flat major, b1YFubxfXb0.mid
# Yachshenko, Taras, Kyiv Blues, BTOXyeqs_D4.mid
# Gardana, Enea, La Luvisella, QqFHLAlelIM.mid
# Clark, Cuthbert Edward, Mon Paradis, gzIJNtUMWD8.mid
# Demarin, Luka, Etude in A minor, Op.7, RYmTwY4omHE.mid
# Raff, Joachim, 2 Paraphrases de salon, Op.70, 6Sy9PYlovv4.mid
# Yachshenko, Taras, Night on the Isar, 2unaly38T_k.mid
# Sarnecka, Jadwiga, Piano Sonata, Op.9, y1A8tuB5vEY.mid
# Ketten, Henry, Caprice-valse, Op.93, F5S4H4VtaQs.mid
# Parish-Alvars, Elias, Sérénade, Op.83, n39xAvSFtZE.mid
# Mozart, Wolfgang Amadeus, Piano Sonata No.16 in C major, K.545, qjk-YRuQZDE.mid
# Scott, Cyril, Pierrette, dbirguBuGcQ.mid
# Del Valle de Paz, Edgardo, Album, Op.32, pMScaIu_I8g.mid
# Bax, Arnold, In a Vodka Shop, GP 162, qP54CjXD1xo.mid
# Zhang, Shuwen, Scherzo No.1 in C major, nd9t4GxY1_A.mid
# Rubinstein, Anton, 6 Preludes and Fugues, Op.53, AxOo77KNdMY.mid
# Melartin, Erkki, Lastuja II, Op.9, GVBnotJJqdw.mid
# Nietzsche, Friedrich, So lach doch mal, eHCI0n-KZ_8.mid
# Sauret, Émile, 4 Morceaux de salon, Op.40, YsqPi59ERfg.mid
# Dédé, Edmond, El pronunciamento, 87XMN2nQx1A.mid
# Harrington, Jeffrey Michael, Piano Prelude No.13, wSlAWLvgM8o.mid
# Singelée, Jean Baptiste, Fantaisie sur des motifs de 'La muette de Portici', Op.71, 95doV1C2toY.mid
# Galos, Giselle, Le Chant du Batelier, FUfN2EHT_Sc.mid
# Carbajo, Víctor, Hopelessnesses, HoARX8tOj8o.mid
# Mayerl, Billy Joseph, Shy Ballerina, Wpeit3DFyIc.mid
# Borch, Gaston, Indian War-Dance, AL68jEgp3O0.mid
# Bedetti, Tiziano, Variazioni su un Tema di Mozart, Qnx92Czy8RM.mid
# Liszt, Franz, 2 Stücke aus Tannhäuser und Lohengrin, S.445, btguV6uPyAs.mid
# Mayer, Charles, Allegro di bravura, Op.102, -_peKn8MccA.mid
# Ekert, Matias, Sonatine, zJDEtWstI_w.mid
# Rubinstein, Anton, Souvenir de Dresde, Op.118, -yO8_jgOolY.mid
# Hiller, Ferdinand, Vermischte Klavierstücke, Op.66, t-PIY8TOavQ.mid
# Berger, Rodolphe, Fleur d'amour, OikM_aSkejo.mid
# Skrzydlewski, Jan, Ballade No.2, Ceuf0hCdQ2w.mid
# Rubinstein, Nikolay, Valse, Op.16, nB83g2AGi_8.mid
# Bachmann, Georges, Fleur d'avril, zi61jeL8-NE.mid
# Fesch, Willem de, La Superbetta, 3MmwmVS-VsY.mid
# Bonnel, Louis, Caprice-Valse, Op.11, kvnFLApyhQs.mid
# Haas, Joseph, Wichtelmännchen, Op.27, NQvEK6ByYl8.mid
# Costa Nogueras, Vicente, Cristina, f86o9hbBNlU.mid
# Carroll, Walter, Water Sprites, 9i3o4FI_LAQ.mid
# Coleridge-Taylor, Samuel, Othello, Op.79, r0CKIgBnzIo.mid
# Liszt, Franz, Albumblatt in E major, S.164, s1vScFa6iuc.mid
# Satie, Erik, Embryons desséchés, nhePRuO9bZY.mid
# Clarke, Jeremiah, A March, CUTnwhr4s9g.mid
# Guelbenzu, José, Mamita, bx9lr-1QWOI.mid
# Ferrari, Carlotta, Madonna sistina, BLLala1w3Eg.mid
# Ponce, Manuel, Mazurka No.27, dHDqLLchrKg.mid
# Hofmann, Richard, 6 Leichte Tonstücke, Op.77, XQyFBvbjEqo.mid
# Martínez García, Salvador, Nocturno, uVE-m80kkww.mid
# Knüpfer, Sebastian, Wenn mein Stündlein vorhanden ist, vVTSSpLaYDQ.mid
# Lefébure-Wély, Louis James Alfred, Caprice, Op.120, N8zTFJIWK5k.mid
# Durand, Auguste, Menuet de Bergame, Op.75, bfVHUIel10I.mid
# Frontini, Francesco Paolo, Capricieuse, UheHd7v-aNw.mid
# Borodin, Aleksandr, Hélène-Polka, 4YGbentlLTk.mid
# Sitt, Hans, Berceuse, Op.56, r1jUmqel1Is.mid
# Mason, William, A Pastoral novelette, Az8vgGj7kIo.mid
# Castelnuovo-Tedesco, Mario, 3 Corali su melodie ebraiche, Op.43, SlSmj36UcZ0.mid
# Hiller, Ferdinand, Impromptus, Op.30, 64mGMijs0KU.mid
# Schubert, Franz, Piano Sonata in A major, D.664, HsMHHlDYlMM.mid
# Chopin, Frédéric, Polonaises, Op.71, k1VOCu-VAQY.mid
# Ketten, Henry, Scherzo No.2, Op.38, IimaCataHDY.mid
# Folwell, John C., Village Chimes, ZfCf2TZs5P8.mid
# Kalachevsky, Mikhail, Nocturne, tXq6cytuZyY.mid
# Tena Manrique, Abraham, Otoño, invierno...otoño, Op.16, ResL9cPf_2s.mid
# Dowland, Robert, A Varietie of Lute Lessons, wqWAHNQ3obU.mid
# Song, Kio, Etude in D-flat major, KY6V-qy3PwI.mid
# Hayden, C. V., Cambridge Gavotte, NuP9fg3rCi4.mid
# Smetana, Bedřich, Louisina Polka, JB 1:1, bcP_ggIBq5Q.mid
# Vītols, Jāzeps, 3 Reminiscences, Op.43, SYDvV5cKmpI.mid
# Shcherbachyov, Nikolay, Mosaïque, Op.15, nm1mHxunkKo.mid
# Cervantes, Ignacio, Serenata Cubana, bimbhjxozMg.mid
# Vaux, Ludovic de, La fille aux cheveux de lin, PzZaHUlYpSw.mid
# Nielsen, Carl, Canto serioso, CNW 67, 9XmmD0j-zJ0.mid
# Grainger, Percy, 2 Musical Relics of My Mother, l1QSZOQwO-o.mid
# Scarlatti, Domenico, Keyboard Sonata in G minor, K.93, 693VMKh6bvM.mid
# Haydn, Joseph, Divertimento in A-flat major, Hob.XVI:46, dKyoCKqh2eI.mid
# Beach, Amy Marcy, Hermit Thrush, Op.92, SNkiywugVmY.mid
# Ladmirault, Paul, 4 Esquisses pour piano, _bV4RvN-Sc8.mid
# Godard, Benjamin, Valse No.2, Op.56, fJFEqVaoPFI.mid
# Williams, Alberto, En la sierra, Op.32, RUDOxFdo6go.mid
# Gussakovsky, Apollon, Scherzo in A major, 4_0brRVtbEs.mid
# Gerber, Edward Enrico, Piano Sonata No.2, gcpEOtgSn-Y.mid
# Schumann, Robert, Kinderball, Op.130, qHJNkZiB7nE.mid
# Rzewski, Frederic, The Liar, yLGeJ9mrNfU.mid
# Kalliwoda, Johann Wenzel, Scherzo, Op.141, sTi-E_sLhgM.mid
# Brahms, Johannes, Variations and Fugue on a Theme by Handel, Op.24, q9tbCkACbGU.mid
# Scarlatti, Domenico, Keyboard Sonata in C minor, K.129, o7jLX6Zpams.mid
# Alkan, Charles-Valentin, Capriccio alla soldatesca, Op.50, dnnTZcIAVvE.mid
# Bohm, Carl, Pluie de perles, Op.191, k6HV7e9VlNY.mid
# Vierne, Louis, Suite bourguignonne, Op.17, vcM5WTQ7wtY.mid
# Liszt, Franz, Mephisto Waltz No.2, S.515, YY2BANuwuQ8.mid
# Allende, Pedro Humberto, 12 Tonadas, r0cOiEu2WAM.mid
# Shirley, Nathan, Etude for One Hand or Two, blqBVZfWXWw.mid
# Liardon, Gaël, Mach's mit mir, Gott, nach deiner Güt, WDcyvLgiCXs.mid
# Díaz, Alejandro, Aves Negras, Op.50, PCxuvorUROY.mid
# Nowakowski, Józef, Rondeau, Op.3, 3fYr-0wgJ-Y.mid
# Peres, Bruno Henrique, Piano Sonata No.2, Op.14, -QWybCUaGRY.mid
# Paulus, Olaf, Novelette, L0Zwl11anAQ.mid
# Raff, Joachim, 3 Klavier-Soli, Op.74, pViLys-5nv0.mid
# Collins, Edward Joseph, 6 Valses caractéristiques, Op.18, PnvWqkPnyz0.mid
# Nin, Joaquín, Mensaje a Claudio Debussy, H6v99V-oFUw.mid
# Tchaikovsky, Pyotr, Impromptu-Caprice, nTc81R9e5Vs.mid
# Suk, Josef, Moods, Op.10, srAOFCYiu1I.mid
# Cervantes, Ignacio, 2 Cuban Dances, F4Qmg6qC6EQ.mid
# Bouillet, Jean-Marc, Viola Sonata, kzoWB6oU2BU.mid
# Weigl, Karl, Bilder und Gesichten, Op.2, XtJqtpSoF8o.mid
# Beethoven, Ludwig van, 10 National Airs with Variations, Op.107, IiopYMSZsl8.mid
# Schütt, Eduard, Scènes champêtres, Op.46, o-zTjJonkls.mid
# Blon, Franz von, Sérénade d'amour, svHYsQuPC8U.mid
# Scarlatti, Domenico, Keyboard Sonata in G minor, K.450, 52yT2MskxlQ.mid
# Manookian, Jeff, Scenes of the Seasons, h-6SLzFuxWY.mid
# Hummel, Johann Nepomuk, Capriccio for Piano, kx41wOYUjAM.mid
# Lyapunov, Sergey, Mazurka No.6, Op.24, vr808FZnHVU.mid
# Hitz, Franz, Le ménestrier, Op.228, wsfdnzKAqqs.mid
# Clérice, Justin, Divina, YgGujAQG7II.mid
# Kistler, Cyrill, Rhönklänge, Op.16, XiHpIuDCXNI.mid
# Bach, Johann Sebastian, Prelude in A minor, BWV 922, 88dJlWFuTYg.mid
# Tchaikovsky, Pyotr, 6 Pieces, Op.21, CCE1Ir2to4Y.mid
# Mendelssohn, Felix, Variations, Op.82, I1OFbeBybdA.mid
# Arensky, Anton, 6 Pièces enfantines, Op.34, RravOyHRYBk.mid
# Mozart, Wolfgang Amadeus, Minuet in D major, K.355_576b, eIjm5unr9ao.mid
# Godowsky, Leopold, 3 Pieces, Op.12, _BGpuyvddCM.mid
# Le Beau, Luise Adolpha, Piano Sonata, Op.8, eJaU1-fsusU.mid
# Heller, Stephen, Rêveries du promeneur solitaire, Op.101, hQmBgJVpam8.mid
# Ravel, Maurice, Le tombeau de Couperin (piano), I_m6hLSpsLc.mid
# Schulhoff, Erwin, Hot Music, WFP5nguGTAI.mid
# Bernet, Atie, Invention No.4, 6WVt0MZz2NA.mid
# Campion, François, Gavotte en Rondeau, wjFGAm3aVcE.mid
# Clementi, Muzio, Piano Sonata, Op.20, nl4rYMReGbE.mid
# Medtner, Nikolay, Theme with Variations, Op.55, HoWfYpu-jiU.mid
# Saint-Saëns, Camille, 6 Études, Op.52, goY8Q_nfZWU.mid
# Donizetti, Gaetano, Sonata for Piano Four-Hands in D major, A 569, cYm14iGkB78.mid
# Karolak, Hans-Jürgen, Hastings, Altstadt, 2A70Q49x5CA.mid
# Falla, Manuel de, Serenata Andaluza, UdKYU-x0j_g.mid
# Simpson, Daniel Léo, Invention No.11 in E-flat major, vBFW0ZpHUY8.mid
# Konyus, Georgy, Largo, Op.39, bkoqTMq5F_M.mid
# Egghard, Jules, Le plus beau rêve, Op.180, TAQoSR4woGw.mid
# Stanchinsky, Aleksey, Etude in F minor, p21wNn8OkiU.mid
# Campion, François, Gavotte en Ré Mineur, 88e2TpeQo2o.mid
# Cappa, Antonio José, Recuerdos de la Alhambra, vBCvjkFrd3I.mid
# Pijper, Willem, Sonatina No.3, jaNndsUUdbU.mid
# Debussy, Claude, The Little Nigar, P3NCYpdlJo8.mid
# Ranzato, Virgilio, Passione, 115kOwv_JwY.mid
# Mullen, Alfred Frederic, The Enchanted Isle, AF5rJtufSR8.mid
# Lavignac, Albert, Nocturne, M46mYJuXSC8.mid
# Wertheim, Juliusz, 4 Préludes, Op.2, YN9n_n_YSmk.mid
# Berger, Rodolphe, Loin du pays, aEXj5HedSG4.mid
# Scarlatti, Domenico, Keyboard Sonata in F minor, K.466, uthlSgmBYMc.mid
# Wohlfart, Karl, Minnen från Rom, Op.28, pPs2klXghkM.mid
# Carbajo, Víctor, Declamatio, ysn2-v_yn_E.mid
# Kendall, Edwin F., The Manhattan Rag, mY2t53HK9N8.mid
# Heller, Stephen, 30 Etudes Progressives, Op.46, v0jHs_NxnXw.mid
# Henselt, Adolf von, Scherzo, Op.9, 1kbNU9P0Ywo.mid
# Handel, George Frideric, Air in B-flat major, HWV 469, S6eL95P6jvw.mid
# Mayer, Charles, Mazurka in F-sharp major, JO1P7wyngVA.mid
# Charbonnet, Alice Ellen, Danse d'Arlequin, U39F6CUJgTU.mid
# Mentasti, Alessandro, Mazurka in F minor, q3l3axHDnpA.mid
# McEwen, John Blackwood, Vignettes from La Cote d'Argent, VvN7ZbFkcTQ.mid
# Balakirev, Mily, Waltz No.1, FOk31fDqexY.mid
# Purcell, Henry, Suite in G major, Z.660, lWjhJBnuk8E.mid
# Ježek, Jaroslav, Piano Sonata, ZJObiVtQoXQ.mid
# Mathé, Edouard, Menuet badin, m2qny0fxlSo.mid
# Kéler, Béla, Üstökös-Csárdás, Op.49, 9xObn7nC114.mid
# Valen, Fartein, Variations, Op.23, p0FIPfWExwg.mid
# Henselt, Adolf von, 2 Nocturnes, Op.6, V7x7U7XcUEc.mid
# Fickenscher, Arthur, Verrufene Stelle, nSemIxtP3CE.mid
# Schröder, Hermann, Lieder ohne Worte, Op.9, y6P5zHQP6Z0.mid
# Scriabin, Aleksandr, 12 Etudes, Op.8, loKu_APkKQY.mid
# Scott, James, New Era Rag, q0ITYYqEjZg.mid
# Chesneau, Carl, Lucie, Op.20, sWHbSHF4jTg.mid
# Jungmann, Albert, 3 Piano Pieces, Op.267, T_u0g_votcU.mid
# Jacchini, Giuseppe Maria, Sonata No.5 in D major, pQZuoNRsy-k.mid
# Godowsky, Leopold, Contrapuntal Paraphrase on 'Invitation to the Dance', 1IA5dX5rUb4.mid
# Feinberg, Samuil, Piano Sonata No.1, Op.1, NtDZ2ppQ49Y.mid
# Scarlatti, Domenico, Keyboard Sonata in G minor, K.8, sw2sctUPl9s.mid
# Le Couppey, Félix, Le progrès, Op.24, n71RyL95lFE.mid
# Scott, Cyril, Pastoral Suite, 3qQk08PgTQU.mid
# Saint-Saëns, Camille, Caprice héroïque, Op.106, eveSQ4SEWfw.mid
# Müller, Bernhard Eduard, Am Abend, Op.71, Z_SG0HNLDCY.mid
# Ross, Walter, Variations on »Auprès de ma blonde«, 5kwVH2OPuKo.mid
# Demersseman, Jules, Cavatine, Op.47, qsXg1XnnTgA.mid
# MacDowell, Edward, 6 Idyls after Goethe, Op.28, YiQ-57FopnE.mid
# Handel, George Frideric, Prelude, HWV 562, qxYhUCfhl9Y.mid
# Farnaby, Giles, Tower Hill, FVB 245, sUR44UUADQk.mid
# Dorn, Charles James, Evening Breezes Waltz, GVdxiZXihUo.mid
# Hollaender, Victor, Canzonetta, 4dD8akhPhH4.mid
# Sor, Fernando, Les Adieux, Op.21, FQqmMAnf7KU.mid
# Medtner, Nikolay, Sonata romantica, Op.53 No.1, V5vmwsegQMI.mid
# Backer-Grøndahl, Agathe, 5 Lettere fantasistykker, Op.63, IkN3kVAt-W8.mid
# Miguez, Leopoldo, 12 Peças características, Dpu8gpDiAxg.mid
# Clarke, Jeremiah, The Emperour of Germany March, e-4cr_nt1TM.mid
# Nicholson-Ward, Alexander Robert, 7 Preludes, Op.1, BLDrXC4VxBw.mid
# Reinhold, Hugo, 24 Miniaturbilder, Op.39, Egwt5DjWF9Q.mid
# Balakirev, Mily, Scherzo No.2, bMrA5OibV1w.mid
# Simpson, Daniel Léo, Prelude and Fugue No.6 in D minor, 8mnYYrbFNzs.mid
# Teilman, Christian, Tonebilleder, SVKTdhihqZk.mid
# Duvernoy, Henri Louis Charles, Danse kalmouk, Op.84, JGQNmXl0Ylk.mid
# Bach, Carl Philipp Emanuel, Fantasia in D minor, H.195, nCBfeqDlKb0.mid
# Lyadov, Anatoly, 12 Canons on a Cantus Firmus, z2u8A8F8C6Q.mid
# Lipski, Stanisław, 3 Polnische Tänze, Op.11, lpZIg5rmkfQ.mid
# Mozart, Wolfgang Amadeus, Piano Sonata No.9 in D major, K.311_284c, 49oiE8Tj1UU.mid
# Liszt, Franz, Hungarian Rhapsody No.19, S.244_19, zUeEJn2aezk.mid
# Lefébure-Wély, Louis James Alfred, 24 Etudes, Op.23, 8yO9buYzNFM.mid
# Bachlund, Gary, Prelude, Air and Fugue in C-sharp minor, f-ezSE-TmP0.mid
# Statkowski, Roman, Mazureks, Op.24, 9hszyUFW86g.mid
# Burgmüller, Friedrich, Cavatine de 'Bianca e Fernando', Op.17, 9EimVtJxpOY.mid
# Sterkel, Johann Franz Xaver, Fantaisie in A minor, StWV 226, OuTEr6WBmYU.mid
# Santos Carrión, Julián, Leyenda, 1q1k9u3IaoY.mid
# Duvernoy, Jean-Baptiste, 25 Études progressives, Op.298, -rjSuVCke8M.mid
# Lyapunov, Sergey, Prelude and Fugue, Op.58, lhYATky6EWY.mid
# Melartin, Erkki, 7 Piano Pieces, Op.98, Y-o_JbvvgS8.mid
# Tierney, Harry, Irene, CGb-OdZVnuE.mid
# Ascher, Joseph, La plainte indienne, ry1ZPBLaXgo.mid
# Henselt, Adolf von, Frühlingslied, Op.15, rd_k1JETTOY.mid
# Bates, Michael, Piano Sonata in B-flat major, lp4Y4wdG5XU.mid
# Oberthür, Charles, The Harp that once through Tara's Halls, Op.187, XSGmZoPBPSI.mid
# Boeck, August de, Feuillet d'album, h0jCQ0YnsXA.mid
# Gazzaneo, Paulo, Piano Quartet, y5yqCeqWxL4.mid
# Diabelli, Anton, Sonata for Piano 4-hands, Op.73, QlIR75nqKVo.mid
# Waldteufel, Emile, Etincelles, Op.229, 2TTt2ybsGaM.mid
# Malinowski, Charles, 6 Morceaux rustiques, Op.5, yPX-lLB5IeQ.mid
# Chavagnat, Edouard, Canzonetta, Op.100, BEmH7Cije1k.mid
# Joplin, Scott, Scott Joplin's New Rag, C0vGk5MzVFI.mid
# Gottschalk, Louis Moreau, Union, Op.48, Z5VGofeoosc.mid
# Raff, Joachim, Valse-impromptu à la tyrolienne, WoO.28, j3y8zd3IM-4.mid
# Delaborde, Elie Miriam, Étude de concert No.2, gptqEz8nm7E.mid
# Violette, Andrew, Ringing Changes, FYyUgoPHfiw.mid
# Lyadov, Anatoly, 4 Preludes, Op.46, jZU6b05af3o.mid
# Lowthian, Caroline, Venetia Waltz, nTj8S6tlzdQ.mid
# Cui, César, 3 Romances, Op.3, zxmIkMeu8Iw.mid
# Turina, Joaquín, 2 Danzas sobre temas populares españolas, Op.41, yiUZAVmoups.mid
# Abreu, Zequinha, Tico-Tico no fubá, KyEuFpJuwfc.mid
# Pitoni, Giuseppe Ottavio, Vias tuas Domine, 6BYTq10zgBE.mid
# Grechaninov, Aleksandr, Album d'Andrucha, Op.133, LKL0F9iGRqo.mid
# Sorabji, Kaikhosru Shapurji, Piano Sonata No.1, ofLqtG6xNCI.mid
# Spindler, Fritz, Humoreske, Op.27, kYYL1ttTRFo.mid
# Wheeldon, Herbert Arthur, Oriental Intermezzo, YpEx8CBaiwo.mid
# Weber, Carl Maria von, 8 Pieces, Op.60, GBoOlkkqcDQ.mid
# Sauer, Emil von, Sérénade française, BcKBK08qt-E.mid
# Liszt, Franz, Hungarian Rhapsody No.14, S.244_14, ts2YRBzGF5k.mid
# Baclay, George, Allegretto in F major, Oi1l89xatHw.mid
# Alkan, Charles-Valentin, Paix à la paix, d2hAT8fU7qA.mid
# Nietzsche, Friedrich, Da geht ein Bach, RRhSFN4bFCs.mid
# Scriabin, Aleksandr, 3 Preludes, Op.35, 3IHiuAzTfbY.mid
# Godowsky, Leopold, Netherland Suite, M3rFnNks3hw.mid
# Liszt, Franz, Réminiscences de Lucrezia Borgia, S.400, e-XtfYTLi2Y.mid
# Schubert, Franz, Variations on a Theme from Herold's 'Marie', D.908, BqPEp-5U5Rc.mid
# Friml, Rudolf, After Sundown, 2bkxV9x3Uyk.mid
# Ferroud, Pierre-Octave, Sonatine, B3PhQA0tSRs.mid
# Hovhannisyan, Gor, Duet for Horn and Piano, LcImDkT3rA0.mid
# Dobrowen, Issay, 2 Waltzes, Op.6, 6zQFm125TwI.mid
# Snuggs, Colin Peter, Etude No.10 in F major, 8X-2MEEUquA.mid
# Williams, Frederick Arthur, Shower of Pearls, Op.28, TUl__wqj8mQ.mid
# Rzewski, Frederic, Nano Sonatas, Book 4, iXb-DOOh9nw.mid
# Duncombe, William, Piano Sonatina in C major, PB6rycUU2hU.mid
# Albéniz, Isaac, Barcarola, Op.23, dJ3qmtEcQoA.mid
# Monckton, Lionel John Alexander, The Dancing Mistress, IKg34l1g8Es.mid
# Weber, Carl Maria von, 9 Variations sur un air russe, Op.40, Zkjr16rIVsI.mid
# Coste, Napoléon, Adagio et divertissements, Op.50, S7UJvne0QYg.mid
# Martucci, Giuseppe, Tarantella, Op.6, XrVIbHqy6Ls.mid
# Nuyens, Henri, Valse de salon No.1, lq4iBO3H16Y.mid
# Villoldo, Ángel Gregorio, Don Pedro, kVd69bOtBXM.mid
# Agnew, Roy, Rabbit Hill, iVrPfk_ODOA.mid
# Pabst, Paul, Concert Paraphrase on 'La Belle au Bois Dormant', S2rKzTRWRwY.mid
# Haydn, Joseph, Keyboard Sonata in D major, Hob.XVI:51, jmXWYUwIViE.mid
# Mesquita, Henrique Alves de, A surpresa, slrZswpr_Os.mid
# Marmontel, Antoine François, 2 Menuets, Op.114, YIGKLmYovsU.mid
# Honegger, Arthur, 7 Pièces brèves, H.25, OpIJoTm5nb8.mid
# Koechlin, Charles, 10 Petites pièces faciles, Op.61c, c-7VcX_PNuA.mid
# Gershwin, George, Swanee, xqGI8sSgXbE.mid
# Saliby, José, Piano Sonata No 2 in C major, kKV58Vu06DA.mid
# Souto, Eduardo, O despertar da montanha, sm790h9NzDA.mid
# Sor, Fernando, Souvenirs d'une soirée à Berlin, Op.56, 9d5mj_jzcXM.mid
# Bach, Carl Philipp Emanuel, La Stahl, H.94, qbBxC5Q2Y2M.mid
# Richter, Josef, Lied ohne Worte, D7ycjqaA7bA.mid
# Le Beau, Luise Adolpha, 8 Preludes, Op.12, P98lnVEe3xI.mid
# Manookian, Jeff, Concert Waltz, QQ7d0XeQ6Ck.mid
# Rebikov, Vladimir, Conte de la Princesse et du Roi des Grenouilles, Op.36, Vk-6f8q6Uf0.mid
# Schad, Joseph, Fleur des Alpes, Op.39, k538J8Hoxcw.mid
# Krein, Aleksandr, 5 Préludes, Op.3, aGdvmrTilE0.mid
# Albéniz, Isaac, Suite Española No.2, Op.97, RPFr6VlGXYc.mid
# Praeger, Ferdinand, Allegretto in A-flat major, 5wTBXOb5lf0.mid
# Hummel, Johann Nepomuk, 6 Bagatelles, Op.107, MECpcJV7Nos.mid
# Goria, Alexandre Édouard, Saltarelle, Op.23, KZz5ibJqybU.mid
# Woyrsch, Felix, Improvisationen, Op.44, t143t3h5PPg.mid
# Drozdov, Vladimir, Etude de Concert, KhEWwK3peb4.mid
# Barili, Alfredo, Valse-Caprice, Op.2, Fh9gIdqVrGg.mid
# Fuchs, Robert, Präludium in D-flat major, ARaYzdLPL8c.mid
# Dorn, Charles James, Moonlight Reverie, CLz7AMO-Smw.mid
# Pessard, Émile, 20 Pièces nouvelles, Op.26, AnH5kjhEQBU.mid
# Fuchs, Armin, Oder etwa doch?, O0m7z4JsSYc.mid
# Fauré, Gabriel, Barcarolle No.7, Op.90, DicYMZI9JN8.mid
# Chopin, Frédéric, Waltz in A minor, B.150, algM0c_u99k.mid
# Rachmaninoff, Sergei, 10 Preludes, Op.23, Hj84l05xWg0.mid
# Scarlatti, Domenico, Keyboard Sonata in F minor, K.183, ARtOsBl8Vog.mid
# Alkan, Charles-Valentin, Grande fantaisie sur Don Juan, Op.26, lIRcC2dRV_4.mid
# Cramer, Johann Baptist, Piano Quintet No.1, Op.60, k-EpZs6EfW0.mid
# Hüe, Georges, 3 Rondels dans le style ancien, nNBKzuLP1b8.mid
# Schubert, Franz, Fugue in E minor, D.952, tnbt1VpwMPE.mid
# Scarlatti, Alessandro, Messa à quattro in canone, R.514_8, Qa8v12zFrgE.mid
# Frieman, Gustav, Kujawiak, Op.6 No.2, AGMxPSvQvwM.mid
# Bach, Johann Sebastian, Sinfonia in F minor, BWV 795, qF8-ijUYWU0.mid
# Gottschalk, Louis Moreau, Illusions Perdues, DrjFY0cim6o.mid
# Hiller, Ferdinand, La Danse des fées, Op.9, JLuoiL4OG1w.mid
# Daniel, Jules, Berceuse, smh-dmapdMw.mid
# Iliev, Grigor, Winter Story, sNCQv3FOtdE.mid
# Nicodé, Jean Louis, 10 Poems, Op.22, BL7Jr8O-uiM.mid
# Carbajo, Víctor, Twilights, enZhKN-4NzQ.mid
# Godowsky, Leopold, Meditation, -mAnXfmLdzk.mid
# Franck, César, Prélude, Aria et Final, GvbHP2MHrx8.mid
# Tournemire, Charles, Etudes de chaque jour, Op.70, Vu4cvliZG34.mid
# Ketterer, Eugène, Chant du Lido, Op.177, 85SLyjWi0ns.mid
# Tupinambá, Marcelo, Maricota, sai da chuva, 4I6-GWBqunA.mid
# Schreiner, Hermann L., Gen'l Hancock's Grand March, SEo5bVpmdpI.mid
# Mayer, Charles, Myrthen, Op.106, h_ofvTX3Ljw.mid
# Scharwenka, Xaver, 2 Piano Pieces, Op.22, DO-szoJ3IaE.mid
# Höfle, Paul, Mazurka No.2, rTT5NZZqsCw.mid
# Nin, Joaquín, Canto de cuna para los huérfanos de España, RRZF40wGa4M.mid
# Scholz, Georg, Prelude No.1, V6tQq5dnWPg.mid
# Prudent, Émile, La danse des fées, Op.41, nS3iUWlbKmE.mid
# Zhang, Shuwen, Etude No.20 in C minor 'Colorful Clouds over the Sky Edge', KMMX6a3ffCM.mid
# Simon, Walter Cleveland, March Bizarre, 1-47nJLSAKg.mid
# Caillebotte, Martial, Airs de ballet, 6hhL4cJZJq4.mid
# Mayerl, Billy Joseph, Fascinating Ditty, C0NLNKpplak.mid
# Żeleński, Władysław, Valse-Caprice, Op.9, KyQSpwTrios.mid
# Lyapunov, Sergey, Mazurka No.1, Op.9_1, droWS3bCN80.mid
# Hammerschmidt, Andreas, Erbarm dich mein, AgY-VvoKOZU.mid
# Weyse, Christoph Ernst Friedrich, 8 Etudes, Op.51, s5zlQbEJw44.mid
# Schumann, Robert, Piano Sonata No.1, Op.11, avo4r2KhITU.mid
# Masy, Jean Eudes, Intermezzi, Op.20, 35195o1je40.mid
# Praeger, Ferdinand, Piano Sonata No.35 in C major, ml2YP8N8OaI.mid
# Suk, Josef, 6 Piano Pieces, Op.7, 5_ewZVQleF4.mid
# Courras, Philippe, Habanera, Op.23, ipCZ4K-jszk.mid
# Kölling, Carl, Lose Blätter, Op.147, NK94jkwsnOQ.mid
# Berkahn, Samuel James, Minuet in C major, Nd1G6swk26s.mid
# Delius, Frederick, 5 Pieces, vjOnHfTknxI.mid
# Lefébure-Wély, Louis James Alfred, Pensées intimes, Op.91, Cb2_1CCEQC4.mid
# Efimoff, Alexander, Ballade No.1, Op.10, wUci3Plpbz8.mid
# Waller, Fats, Effervescent, Bmaf0wHmaRs.mid
# Dussek, Jan Ladislav, Keyboard Sonata in G major, n7UUGrpP8-k.mid
# Mozart, Wolfgang Amadeus, Fugue in E minor, K.deest, lEYOKdybPH4.mid
# Schmid, Josef, Arioso in F major, v8YCDHvc8VQ.mid
# Taubert, Ernst Eduard, Quintet for Piano and Winds, Op.48, Zs3LizWovrg.mid
# Srebdolskii, Sergei, Variations, Op.12, n7eeY4G4XKE.mid
# Bach, Carl Philipp Emanuel, Keyboard Sonata in E major, H.39, f9yCLAbCVDA.mid
# Küchenmeister, Wilhelm, Impromptu, Op.31, QOicrylsLTU.mid
# Meyer-Helmund, Erik, 3 Lieder, Op.46, ovzL3kp4gL8.mid
# Rivé-King, Julie, March of the Goblins, q4lCwUtHxHA.mid
# Rachmaninoff, Sergei, Suite No.2, Op.17, 5g3sD7tOKb4.mid
# Chopin, Frédéric, Polonaise in G-flat major, B.36, 2SgbxnqOP3A.mid
# Carcassi, Matteo, Rondoletto on the Favorite Air 'Clic-Clac', Op.41, 5Vcbq8aURww.mid
# Achron, Joseph, Symphonic Variations and Sonata, Op.39, RtRrQwO2Hng.mid
# Schubert, Franz, Allegro moderato in C major, D.347, ticjXvpjU6c.mid
# Debussy, Claude, Hommage à Haydn, ViHQc5JonqY.mid
# Beach, Amy Marcy, The Fair Hills of Eiré, Op.91, EuwOdIHlCp4.mid
# Mullen, Alfred Frederic, Au Carnaval, vlRNQRD_1ZE.mid
# Cobb, George L., Aggravation Rag, BmJUaiWuHss.mid
# Poulenc, Francis, Élégie, FP 168, -c2jC0eJq7Y.mid
# Lange, Gustav, Nordisches Lied, Op.152, zJs2j-6Ygd8.mid
# Mozart, Wolfgang Amadeus, Allegro in C major, K.484e, CJe3ISkn-RM.mid
# Gibbons, Orlando, French Coranto, MB 38, 3dvEYK4KWX0.mid
# Granados, Enrique, El jardí d’Elisenda, KK2kghyqZKo.mid
# Séverac, Déodat de, Les naïades et le faune indiscret, 5en6ZZgVADE.mid
# Pearson, Kevin, I Dream of You, j6-YKgKXk38.mid
# Echeverría, José María, Los toreros, Op.31, 9Pt6mFv7rl0.mid
# Pachman, Jason L., Fugue No.21 in B-flat major, hGPcZGLXngM.mid
# Mozart, Wolfgang Amadeus, Minuet in F major, K.4, HwxNF9Hmz_s.mid
# Alkan, Charles-Valentin, Grande Sonate 'Les Quatre Ages', Op.33, pyUvxGxetcI.mid
# Arakelian, Grigor, Tragic Dance, QEbp6f9hTVM.mid
# Victoria, Tomás Luis de, Petrus beatus, kQXsORcMNLM.mid
# Schubert, Franz, Piano Sonata in C major, D.279, dm4NFhDjVno.mid
# Frey, Emil, Kleine slavische suite, Op.38, DMGynkJFvmY.mid
# Pauer, Max, 3 Klavierstücke zu vier Händen, Op.10, zW_hGnFZnZE.mid
# Franck, César, Prélude, Fugue et Variation, Op.18, tW4-lDMv4nI.mid
# Bach, Johann Sebastian, Sinfonia in C major, BWV 787, 0YsHo4-HLlM.mid
# Stanchinsky, Aleksey, Piano Sonata in E-flat minor, HuJzbRh-5nE.mid
# Mason, William, Spring Flower, Op.21, DHPMEcStjgg.mid
# Turina, Joaquín, La Venta de los Gatos, Op.32, DW9wvXJGGhY.mid
# Shcherbachyov, Vladimir, Chimes, h3hCCflk4VE.mid
# Taubert, Wilhelm, Lyrische Stücke, Op.106, mqzoT6r247I.mid
# Costa Nogueras, Vicente, En el Alcazar, Op.119, f86o9hbBNlU.mid
# Bonis, Mel, Les Gitanos, Arjb_zjU-CA.mid
# Quidant, Alfred, Grande Etude-Galop, Op.21, 3jCGIabp98w.mid
# Merino Martínez, Aitor, Satwork, 37Vd4MiL-Fo.mid
# Marando, A., Bagatelle No.3, Op.13, 1OBSxw-Y5ng.mid
# Ghavidel, Ata, Fugue in C major, FUJpXpCbNgw.mid
# Werner, Albert, Trauermarsch, Op.20, -mEDlJcSlgw.mid
# Zweig, Otto, Suite, Op.6, RXnBSWZbcUc.mid
# Czerny, Carl, Quatuor concertant No.1, Op.230, v_YU6NYDhWw.mid
# Mendelssohn, Felix, Variations, Op.83, SIXArkTH_c0.mid
# Saint-Saëns, Camille, Suite, Op.90, OpM2sEWzUmo.mid
# Marmontel, Antoine François, Nocturne élégant, Op.22, QszLjrq_FWQ.mid
# Junck, Christian, Harp Sonata No.1 in G major, nE07aUmAh6k.mid
# Todt, Johann August Wilhelm, La coquinette, Op.33, x54_UGanB8A.mid
# Martínez Rücker, Cipriano, Mazurka No.2, Op.32, T_rzCfoI9U8.mid
# Zhang, Shuwen, Fantasie Variations on iPhone Ringtones, EgcwcioIo3A.mid
# Beatty, Stephen W., Trio for Oboe, Clarinet and Bassoon, Op.71, xRNngXIKDHM.mid
# Scriabin, Aleksandr, 4 Pieces, Op.51, hcUyPiigcgM.mid
# Raff, Joachim, Fantaisie-Polonaise, Op.106, 2hQFmqz8bJU.mid
# Beethoven, Ludwig van, Piano Sonata No.11, Op.22, 0_5iQCV62S4.mid
# Della-Tolla, Antoine, La Danse des Sylphes, 2UR6rzmUgWg.mid
# Ganne, Louis, Valse des baisers, 7z6mMi1nU3g.mid
# Hitz, Franz, Danse des Guarany, Op.232, ji1cvsoTzPs.mid
# Morales, Cristóbal de, In illo tempore assumpsit Jesus Duodecim, 0CueASx7r6E.mid
# Koechlin, Charles, L'ancienne maison de campagne, Op.124, -KcUM25aktY.mid
# Borch, Gaston, Andante pathétique, jvoLnGv6tXk.mid
# Godowsky, Leopold, Suite for the Left Hand, BtkdaARV_7o.mid
# Teilman, Christian, Drömmeri, KBsTiJZHMbs.mid
# Sherwood, William H., Autumn, Op.15, FlfqfsDasSM.mid
# Simpson, Daniel Léo, Piano Sonata in F major, 1jRAi5REz0c.mid
# Stanford, Charles Villiers, 4 Irish Dances, Op.89, 2_f2dHjGWsI.mid
# Hiller, Ferdinand, Modern Suite, Op.144, 6QAyq6cBiR4.mid
# Koreshchenko, Arseny, 6 Morceaux, Op.19, WlfPlSujRm8.mid
# Chaminade, Cécile, Menuet, Op.5, ALrNdpqjQ6Y.mid
# Rinck, Christian Heinrich, Abend wird es wieder, OqUhmPmsGzM.mid
# Fauré, Gabriel, Barcarolle No.1, Op.26, Z0-SOATtK6c.mid
# Ries, Ferdinand, A Moldavian Air with Variations, Op.105 No.4, lOUZDzYhWMg.mid
# Respighi, Ottorino, Piano Sonata, w7rdjbnv918.mid
# Mussorgsky, Modest, Meditation, CHIux8A61Tw.mid
# Mills, Kerry, Rastus on Parade, TjhWXLRXln0.mid
# Scott, James, Climax Rag, qKhoF2YkYvU.mid
# Gottschalk, Louis Moreau, Le Chant du Martyr, 22UFZg8AANE.mid
# Agnew, Roy, Holiday Suite, p6kK1oMvvpk.mid
# Lushpa, Ilia, Tragedy, iLiIhYInjFE.mid
# Nichifor, Serban, O, valuri..., lHNntY32XiA.mid
# Tena Manrique, Abraham, 2 Ausencias y Epílogo, Op.2, G1uqnuUba4g.mid
# Sandré, Gustave, 3 Morceaux, Op.52, re0-uvYa5C0.mid
# Wandelt, Bruno, Widmung, dD7i92f0ZB8.mid
# Liszt, Franz, Siegesmarsch, S.233a, CE3t63_UHwc.mid
# Krein, Aleksandr, 2 Pieces on Turkish Themes, Op.46, qgmLdOk7i2A.mid
# Verroust, Stanislas, Solo de concert No.4, Op.77, YqjO7i65ST4.mid
# Calvo, Luis Antonio, Lejano Azul, RZYEvNxVsms.mid
# Wachs, Paul, Valse parisienne, 2j8ax92E558.mid
# Slavenski, Josip, Sonata, Op.4, pn9bZH4uzh0.mid
# Malats, Joaquín, La morena cubana, XjNc_IrnXRg.mid
# Scott, James, The Suffragette, LRct4lfu1M4.mid
# Wagner, Richard, In das Album der Fürstin Metternich, WWV 94, VDhul7bCB60.mid
# Longo, Alessandro, Pagine d’Album, Op.1, qR2Z3peoOhg.mid
# Lyadov, Anatoly, Variations sur un thème de Glinka, Op.35, gFg_gSTeCeE.mid
# Alkan, Charles-Valentin, 25 Preludes, Op.31, tly_AbXkeCI.mid
# Mozart, Wolfgang Amadeus, Fantasia in C minor, K.475, Ui9pyxdVX6Y.mid
# Gonzaga, Chiquinha, Grata esperança, SonEJhPIAqs.mid
# Pierné, Gabriel, Impressions de music-hall, Op.47, y-MSnyeO9yY.mid
# Tourrier, Theodore John, Valse de concert, U2s4I4PgOjI.mid
# Prokofiev, Sergey, Piano Sonata No.8, Op.84, usTKWIFVQHI.mid
# Kirchner, Theodor, Alte Erinnerungen, Op.74, RKJ1FGWmk-g.mid
# Menter, Sophie, Etude, Op.9, IPsKdu97ggA.mid
# Handel, George Frideric, Wenn Christus, der Herr, zum Menschen sich neigt, NYWF7r6aGMU.mid
# Schubert, Franz, Rondo in E major, D.506, BTRrIxxxoug.mid
# Berens, Hermann, Idylle, Op.34, uZpATphI-gw.mid
# Kleczyński, Jan, Prelude, Op.11 No.1, CLLaDN3mPVg.mid
# Bach, Johann Sebastian, Invention in G major, BWV 781, jVHqIK13-nk.mid
# Turina, Joaquín, Álbum de viaje, Op.15, m0nTnXS4yhw.mid
# Liszt, Franz, Aus Lohengrin, S.446, x-l_lG9MQvk.mid
# Mendelssohn, Felix, Fantasie, Op.28, _VTlaGREM7I.mid
# Czerny, Carl, Musikalische Theater-Bibliothek für die Jugend, Op.463, SOT9qiEbjG4.mid
# Praeger, Ferdinand, Nocturne in A-flat major, ENbNi63vc9c.mid
# Krasev, Mikhail, Little Suite, Op.1, Bu6DH15sQjI.mid
# Burgmüller, Franz, 2 Piano Pieces, Op.100, ktD3aBPwyUU.mid
# Pachman, Jason L., Prelude No.16 in B-flat minor, jR5Slc29ysM.mid
# Zelenka, Jan Dismas, 9 Canons, ZWV 191, t3ZJ8a6tfRA.mid
# Stanford, Charles Villiers, 3 Waltzes, Op.178, AE18vyYxFB8.mid
# Ladurner, Ignace Antoine, Sonata for Piano 4-Hands, Op.6, 2dXANMAbJ_4.mid
# Schytte, Ludvig, 2 Morceaux, cuLRuCA-KkE.mid
# Tinel, Jef, Dansende muggen, i3qF6A-Jpfw.mid
# Minot, Adolf, Dramatic Agitato, PudM1QHU0Qw.mid
# Locke, Nicholas, Duet for 2 Pianos in B-flat minor, Op.3, TBISkG9sBWo.mid
# Chaminade, Cécile, Barcarolle, Op.7, LFJqUakPcy0.mid
# Reinecke, Carl, Impromptu, Op.66, zSwW_VNF9vI.mid
# Duncombe, William, Fanfare Minuet, uzCyVK7uaCY.mid
# Haydn, Joseph, Keyboard Sonata in E minor, Hob.XVI:34, 3TTbrU8bFdM.mid
# Bach, Carl Philipp Emanuel, Fantasia in C major, H.284, I6Can09AU-0.mid
# Volkmann, Robert, Deutsche Tanzweisen, Op.18, Ct-Wr8ev8h0.mid
# Chaminade, Cécile, Étude humoristique, Op.138, lUm9NANcNv4.mid
# Kramer, A., La prière d'une mère, KFNpqUPZRTc.mid
# Scott, Cyril, Lotus Land, Op.47 No.1, DoqDR5Zvu_M.mid
# Stefani, Józef, Polonaise melancholique, HveZII_3uvk.mid
# Röntgen, Julius, Piano Sonata No.2, Op.10, 0JJLyj1I58A.mid
# Urspruch, Anton, Präludium und Capriccio, Op.22, xXetBMbPaLQ.mid
# Novák, Vítězslav, 2 Valašské tance, Op.34, BtSe66VZ5LE.mid
# Bax, Arnold, Piano Sonata No.1, GP 127, nsegZt6isBM.mid
# Jongen, Joseph, 2 Pieces, Op.33, KNTxhXTrDl0.mid
# Pearson, Kevin, When I'm Lost, h_Ym8IwPBSE.mid
# Brahms, Johannes, Variations on a Theme by Paganini, Op.35, 1EIE78D0m1g.mid
# Moszkowski, Moritz, 3 Morceaux, Op.73, s9AHQEicH10.mid
# Schubert, Franz, Piano Sonata in A-flat major, D.557, TxbqZ0TX7u0.mid
# Albéniz, Pedro, Isla de la cascada de Aranjuez, Op.70, r-tBdPlUz4w.mid
# Clementi, Muzio, 3 Piano Sonatas, Op.50, y8roMt3NR7Y.mid
# Dvořák, Antonín, 8 Humoresques, Op.101, 38JFo_E4rc0.mid
# Couperin, Louis, Invitatoire de la Trinité, OL 52, yGtO06vndj0.mid
# Marcailhou, Gatien, Le torrent, 712DsHGHE7k.mid
# Joplin, Scott, Peacherine Rag, Z8c8eFXNolg.mid
# Zhang, Shuwen, Etude No.16 in B-flat minor 'Tempest', M0S1NUoP8aQ.mid
# Czerny, Carl, Grand Exercise, Op.82, 54u6UJ8ZBT8.mid
# Pratt, Paul Charles, Spring Time Rag, h7M-rSf56lw.mid
# Gabrieli, Andrea, A le guancie di rose, FNAvC-dS_sM.mid
# Saint-Saëns, Camille, 6 Études, Op.111, vDH5CYeFLZk.mid
# Yamada, Kōsaku, Poèmes in 7 Teilen 'Sie und er', fWt71F2C7k0.mid
# Oesten, Theodore, Maiblümchen, Op.61, FeuvEBysk-k.mid
# Appenzeller, Benedictus, Musae Iovis, Fi89mGidzF0.mid
# Backer-Grøndahl, Agathe, 5 Songs, Op.46, ELeX0GPhIbc.mid
# Nollet, Eugène, Elegy, Op.88, ry1XZjFXJXw.mid
# Ries, Hubert, 3 Morceaux de salon, Op.23, IM8cTmvjYes.mid
# Victoria, Tomás Luis de, Hostis Herodes impie, uxmox9w4k2I.mid
# Lamb, Joseph Francis, Ethiopia Rag, x1syJ0cls3E.mid
# Warren, George William, The Song of the Brook, HiSsJRvX3RA.mid
# Scarlatti, Domenico, Keyboard Sonata in G major, K.375, NDFb-_92xxo.mid
# Liszt, Franz, Invocation, S.172c, SVUYifY08y4.mid
# Bach, Carl Philipp Emanuel, La Capricieuse, H.113, QcC7KiHOg7w.mid
# Lafrenière, Jean-Baptiste, Raggity Rag, LI1NF5dH05I.mid
# Henriques, Fini, Aphorismen, Op.6, kHg1pty4hx8.mid
# Żeleński, Władysław, Piano Sonata No.2, Op.20, iw4oMPJnC34.mid
# Raff, Joachim, Impromptu-valse, Op.94, ICj_pB7zaeo.mid
# Widor, Charles-Marie, Valse oubliée, cW6ZSxVV5os.mid
# Bollman, Henry, Murmuring Brook, m3a4_JEaMec.mid
# Naegel, Dustin, Das Schloss an der Wupper, gRkOC8ikc_w.mid
# Friedman, Ignaz, 4 Klavierstücke, Op.27, h0hvkTJ58IE.mid
# Beatty, Stephen W., Etude for Piano, Op.375, INR_PT-6W1Q.mid
# Harrington, Jeffrey Michael, Prelude No.1 for 19ET Piano, Sp1yz5D70Qc.mid
# Williams, Alberto, Hueyas, Op.33, lEI3NE1EmI4.mid
# Wurm, Mary, Piano Studies for the Left Hand, Op.51, TmhYcLynKSk.mid
# Martinů, Bohuslav, Spring in the Garden, H.125, kozKjH3F6ik.mid
# Berkahn, Samuel James, Rag No.1, Ihq059U-weI.mid
# Sabaneyev, Leonid, Piano Sonata, Op.15, _6D06t9A9FY.mid
# Scriabin, Aleksandr, 2 Mazurkas, Op.40, CyOCa0OtgB0.mid
# Mason, William, Romance-étude, Op.32, QPtbvWd78ZM.mid
# Nicolai, Carl Richter, Gavotte-Impromptu in G major, piblGh5wfOU.mid
# Kryukov, Vladimir, Piano Sonata No.2, Op.14, PZN7XLKzLDI.mid
# Chopin, Frédéric, Études, Op.25, gLZ4WJiDldU.mid
# Gobbaerts, Louis, Marche des braves, 4jxcoSC1tAk.mid
# Balakirev, Mily, Piano Sonata No.1, Op.5, xx7D4Vu2ryM.mid
# Rawlings, Charles Arthur, Amour Tendre, svI3GwbgTyo.mid
# Scott, James, Modesty Rag, s184TLoxTp0.mid
# Kopylov, Aleksandr, Valse, Op.6, LXzztjbeZ-Y.mid
# Dobrowen, Issay, Ballad No.2, Op.9, R1IGrf0aDoo.mid
# Plante, Cyril, Ballade No.2 for Piano, Op.194, 2lRLQXc3Dy4.mid
# Brahms, Johannes, Piano Sonata No.1, Op.1, 66oJL0JZ9_E.mid
# Parlow, Albert, Variations on a Russian Folksong, Op.150, w0gzNXJgr-E.mid
# Soro, Enrique, Berceuse, 7oKunO0YfGs.mid
# Frontini, Francesco Paolo, Dolce voluttà, twtvxlfuEpU.mid
# Glazunov, Aleksandr, 2 Pieces for Piano, Op.22, uh887cAb8xc.mid
# Mourey, Colette, Festive Voluntary, nbMPXKSMBsQ.mid
# Krentzlin, Richard, Festpolonaise, Op.11, -nE34IFzNj0.mid
# Albrecht, Ludwig, Elegy in A-flat major, Vc7fN8yzLrs.mid
# Kowalewski, Jakub, Tre pezzi di sonata, 3bv8FTIWrz0.mid
# Satie, Erik, 3 Valses distinguées du précieux dégoûté, EAxiVpaKVmw.mid
# Scarlatti, Domenico, Keyboard Sonata in G minor, K.30, ebmMBvuxRkg.mid
# Adalid, Marcial del, Un Recuerdo, wjSOPn534So.mid
# Palmgren, Selim, Aria, txmpHhYgaIs.mid
# Fleuret, Daniel, Organ Sonata No.1, Op.10, bJPcjoHWoZg.mid
# Itiberê, Brasílio, Poème d'amour, Op.22, gcgJY_DOUhU.mid
# Ivanov-Boretsky, Mikhail, 6 Preludes, Op.19, 64iXXC3v5Ww.mid
# Nevin, Ethelbert, En Passant, Op.30, srxuL8Iyjq8.mid
# Dessau, Bernhard, Concerto im alten Stil, Op.55, nxZoaSRRPDs.mid
# Soupelin, Meliton George, 8 Sketches, W2A-9bVREhY.mid
# Igielman, Benjamin, Cat Rag, IJmBMbTxCzk.mid
# Gurlitt, Cornelius, Technik und Melodie, Op.228, PGCSoN1Hv6Y.mid
# Bach, Johann Sebastian, Prelude and Fugue in C-sharp major, BWV 872, QEqBamNZDEE.mid
# Lyapunov, Sergey, Valse-Impromptu No.2, Op.29, v60FMWkGlJ8.mid
# Somervell, Arthur, 3 Original Pieces, 238Bw80E2Vk.mid
# Gigout, Eugène, Interlude in F major, e4tfeJhEiMw.mid
# Brüll, Ignaz, Piano Sonata, Op.73, 4jG3elROzw8.mid
# Wolff, Édouard, Barcarolle et Chansonnette, Op.331, JDBfnJ0MrvE.mid
# Ornstein, Leo, Musings of a Piano, SO 65, 5MU2T2I1rOA.mid
# Tchaikovsky, Pyotr, Theme with Variations in A minor, CVUr-dc1flM.mid
# Chopin, Frédéric, Waltz in E minor, B.56, ETcsMMq9LYE.mid
# Akimenko, Theodore, 3 Danses idylliques, Op.35, ZP-oDJ7dBsw.mid
# Stojowski, Sigismond, 5 Miniatures, Op.19, 7ZSRw-q8ILM.mid
# Durand, Auguste, Babillage, Op.81, Nq1QKpyJxFU.mid
# Carcassi, Matteo, Variations sur l'air favori Petit Blanc, Op.29, 9rn_i8rhPrA.mid
# Hiller, Ferdinand, All'antico, Op.137, TJJwZqtBDhc.mid
# Debussy, Claude, Pour le piano, KLicw5ryMpQ.mid
# Werner, Auguste, Mignonnette, Op.22, 39ED9uhcnlA.mid
# Paschalski, Konstanty, 3 Pieces, Op.20, hn7lT5E-TTo.mid
# Labriola, Pietro, Il primo amore, EluaB1QAkGY.mid
# Song, Kio, Prelude in E-flat major, I4RQWP-ZQmY.mid
# Holst, Gustav, Chrissemas Day in the Morning, H.165, 7LVQKIs7kA8.mid
# Vilinsky, Mykola, Ballad in the Form of Variations, Op.4, TE1Y2AQIWZY.mid
# Schubert, Franz, 6 Ecossaises in A-flat major, D.697, iq7uEDJozyM.mid
# Beethoven, Ludwig van, Piano Sonata No.21, Op.53, CkzsUP4VmJI.mid
# Gurlitt, Cornelius, 4 Sonatinas, Op.214, aXky0bRa3g0.mid
# Sowinski, Albert, 12 Études mélodiques, Op.124, zA8EbqIxqmI.mid
# Aksyonov, Semyon, Etude in G major, atoyZOOjndw.mid
# Czerny, Carl, Variations brillantes sur un thême de l’opéra 'I Capuleti e i Montecchi', Op.295, 0feSrNm3zgA.mid
# Kleven, Arvid, Appasionato!, ISjWUU_gclM.mid
# Myaskovsky, Nikolay, 9 Piano Pieces, Op.73, cGz_adshZ-Y.mid
# Stahl, William C., Golden Bell Waltz, gmrKI53VUVQ.mid
# Ropartz, Guy, Fugue in E minor, L2hNEqeDz5I.mid
# Leszczewski, Wladislaw, Fugue No.2, itvGdURMfbM.mid
# Williams, Frederick Arthur, A Trip to Fairyland, Op.95, gDE2rKnYev4.mid
# Schubert, Franz, 10 Variations in F major, D.156, hLm0_ROztEs.mid
# Mikuli, Carl, Mazurka, Op.10, yQZHj11xQT8.mid
# Herbert, Victor, Under the Elms, Hk_5V4xWgHE.mid
# Johnson, Charles Leslie, School Life, v2NnmyywnAM.mid
# Klein, Fritz Heinrich, Die Maschine, Op.1, sgSBs4Dq7Co.mid
# Bizet, Georges, Romances sans paroles, e9NnKUXru9w.mid
# Hindemith, Paul, 8 Walzer, Op.6, _RuCVvLWURs.mid
# Rebikov, Vladimir, Aus dem Tagebuche, Op.33, Ci--06lc1oA.mid
# Lie, Sigurd, 4 Pianostykker, o3Ai-5DMA4o.mid
# Malibrán, María, Au bord de la mer, MvBsEVfVsWQ.mid
# Ludenhoff, Martin, Etude for Two 3, J-sxjM4qxA4.mid
# Boisdeffre, René de, 3 Romances sans paroles, Op.1, R_rW0tjX8lw.mid
# Schütt, Eduard, Lose Blätter, Op.13, UJVF_hzlh6g.mid
# Liebling, Emil, Albumblatt, Op.18, pJXT30nQXNA.mid
# Schytte, Ludvig, Zu Zweien am Klavier, hn7jDy6SyxU.mid
# Seixas, Carlos, Toccata in D major, P-Ln T45.20, sOddYgs79nI.mid
# Missa, Edmond, La légende de Saint François d'Assise, Xv43Q3l1JJ0.mid
# Beethoven, Ludwig van, Piano Sonata No.22, Op.54, bbB6aqHGuKM.mid
# Scharwenka, Xaver, Album for the Young, Op.62, by28uWC8GCg.mid
# Tena Manrique, Abraham, 2 Preludios, Op.11, oTSgydEKOls.mid
# Niemann, Walter, Porzellan, Op.120, 50HT7Qyescw.mid
# Chauvet, Alexis, 4 Morceaux de genre, jBVesBYgA1M.mid
# Mozart, Wolfgang Amadeus, Romance in A-flat major, K.Anh.C 27.04, UEpJALYMVhM.mid
# Mozart, Wolfgang Amadeus, Piano Sonata No.15 in F major, K.533_494, tk9fa1CTY9k.mid
# Chizat, Emile, Nuits perdues, CbyMVMVcUfA.mid
# Schubert, Franz, Der Geistertanz, D.15a, uw1DmmVgyJY.mid
# Jacobs, Robert Walter, Little Sinners Rival, fpWYcVi8hWs.mid
# Wot, Felix Firmiana, Piano Sonata No.1 in B-flat major, Op.192, iernqkp5-Ng.mid
# Gershwin, George, Idle Dreams, qyrVxxzWn1w.mid
# Turina, Joaquín, Margot, Op.11, Y6OH047yTmA.mid
# Amthor, Wilhelm, Im deutschen Alpenlande, fV4RfbGnD44.mid
# Mendelssohn, Felix, 3 Preludes, Op.104a, suPJ9yazkTs.mid
# Gonzaga, Chiquinha, Alerta!.., Ks5qrdXvbDw.mid
# Sauter, Louis, Apophtegmes, j5fM3KxKoJ8.mid
# Kromolicki, Joseph, Intermezzo, Op.49 No.2, N5XSTTq882U.mid
# Marmontel, Antoine François, 3 Rêveries, Op.95, Te9_fq-PGec.mid
# Vanegas, Roy, The Dedication, XFYuID2PZ9c.mid
# Carafa, Michele, La violette, cJnA567RO3I.mid
# Mozart, Wolfgang Amadeus, Piano Sonata in F major, K.Anh.29_590a, bUh99lCe1tU.mid
# Liszt, Franz, Grande paraphrase de la Marche pour le Sultan Abdul-Medjid Khan, S.403, GExJGk3pHb8.mid
# Hummel, Johann Nepomuk, Piano Sonata No.6, Op.106, iUygu4cXHAM.mid
# Nazareth, Ernesto, Brejeiro, QP6OLwb9w50.mid
# Di Gesu, Massimo, Ampelomorfismi, S9Bh63Mxu8k.mid
# Liszt, Franz, Hungarian Rhapsody No.8, S.244_8, wUy7t0OvxeU.mid
# Bach, Johann Sebastian, French Suite No.2 in C minor, BWV 813, FU0jr1obOao.mid
# Czerny, Carl, Das moderne Klavierspiel, Op.837, 9YJlw-o7DUM.mid
# Scarlatti, Domenico, Keyboard Sonata in D major, K.443, SkN8h63vd8w.mid
# Hermann, Pál, Invenzioni a tre voci, iOhGuUIG0BE.mid
# Liszt, Franz, Rákóczi-Marsch, S.117, -6BLCTQPMs0.mid
# Tchaikovsky, Pyotr, Capriccio, Op.8, Z2-HiMxki-8.mid
# Reger, Max, Aus der Jugendzeit, Op.17, DOqo4_2Aogk.mid
# Friedman, Ignaz, Stimmungen, Op.79, _Yncxyhp8_g.mid
# Josten, Werner Erich, Piano Sonata, g1d4VKb5WNA.mid
# Kopylov, Aleksandr, 3 Feuilles d'album, Op.26, IOP-jlGWxrE.mid
# Mozart, Wolfgang Amadeus, Fantasie in F minor, K.Anh.32, c7bBMzFn9_Q.mid
# Simpson, Daniel Léo, Piano Sonatina in A major, JVpsfK2DCEw.mid
# Scriabin, Aleksandr, 4 Pieces, Op.56, ma-r9V9kOJg.mid
# Rameau, Jean-Philippe, Suite in E minor, RCT 2, 0VNyATVV2o4.mid
# Handel, George Frideric, Suite in D minor, HWV 428, J04HbcvNN7s.mid
# Scholtz, Herrmann, Andante amoroso, Wv7CejLszts.mid
# Madetoja, Leevi, Kuoleman Puutarha, Op.41, ep-79AIwmhA.mid
# Schumann, Clara, 3 Romances, Op.11, emWwJwiEnF0.mid
# Liszt, Franz, 5 Klavierstücke, S.192, KU3KglL3deA.mid
# Prudent, Émile, Fantaisie sur Lucie de Lamermoor, Op.8, 7QS79-OznqA.mid
# Schumann, Robert, 4 Nachtstücke, Op.23, iuZmLa6-yFs.mid
# Weinberger, Karl, 2 Lieder ohne Worte, KLIY1omd-vg.mid
# Godowsky, Leopold, Twilight Thoughts, A3e3LhSoOzE.mid
# Tavan, Émile, Grande fantaisie sur 'La somnambule', hbIiHM3qSMQ.mid
# Eberl, Anton, Piano Sonata in C minor, Op.1, NTm8wQaCAk4.mid
# Dussek, Jan Ladislav, Piano Sonata in E-flat major, Op.18 No.3, P-Q5aBAw-T4.mid
# Kuhlau, Friedrich, Piano Sonata, Op.4, o26BxbxDRcI.mid
# Marston, George, Album for Children, pYFTxZxALBk.mid
# Satie, Erik, Premier menuet, RdsWNcv1uqQ.mid
# Hermann, Pál, Toccata for Piano, RXnrG2OlifI.mid
# Brosig, Moritz, Fantasia No.1, Op.53, rsgymyM2tBo.mid
# Comellas, José, Sonate brillante, Op.21, aQ4Y0r9PPcc.mid
# Buongiovanni, Giovanni Francesco, Palomma 'e notte, 6EcmpS5ocm4.mid
# Aubert, Louis, Esquisse sur le nom de Fauré, eh688BAjUZ8.mid
# Godard, Benjamin, Romance Sans Paroles, Op.120, poYkMGj7rZQ.mid
# Balakirev, Mily, Waltz No.5, DdBwYFGDpkM.mid
# Losy, Jan Antonin, Tombeau, B8_SVhTg5mI.mid
# Mayerl, Billy Joseph, I Breathe on Windows, 1g69OAOduOI.mid
# Carbajo, Víctor, The Alphabets of the Foam, qAc9o3Rc9zA.mid
# Tinel, Jef, De kerels, -MfHhG5p40E.mid
# Sauer, Emil von, Sempre Scherzando, NJsl5-EkdLM.mid
# Beach, Amy Marcy, Nocturne, Op.107, 5UHayQka-ow.mid
# Scriabin, Aleksandr, Feuillet d'album, Op.58, Yfa_uMYx6KM.mid
# Macchi, Claudio, Romanza senza parole 5, eWb_FjvR_6M.mid
# Smith, Sydney, Caprice espagnol, OYHhUaWWCkw.mid
# Broca, José, Recuerdo Triste, oDgPPU0kGtw.mid
# Sauer, Emil von, Couplet Sans Paroles, JkTK34x1OPI.mid
# Hartmann, Ludwig, Andante in E-flat major, tzCPEUwP4Ag.mid
# Beliczay, Gyula, Gavotte, Op.43, 5h6jnSF4ZzA.mid
# Carbajo, Víctor, Yearning Waltz, sQLvv1TU6_E.mid
# Ries, Ferdinand, Introduction and Rondo, Op.161, m_vk34DiZBA.mid
# Pijper, Willem, Piano Sonata, OcxJViDvfp4.mid
# Eilenberg, Richard, Die Mühle im Schwarzwald, Op.52, qlNElABiHYU.mid
# Alkan, Charles-Valentin, 3 Marches quasi da Cavalleria, Op.37, eFaEyZsdL7U.mid
# Kozeluch, Leopold, Piano Sonata, Op.38 No.3, 83zpGfmUxZc.mid
# Heller, Stephen, Nocturne, Op.103, _IuxZ9J7YWs.mid
# Prokofiev, Sergey, Piano Sonata No.5, Op.38_135, hUdfYil_TbU.mid
# Högn, August, Grablied No.4 in F major, Op.20, lzHCAoGhDI0.mid
# Poulsen, Brian Stenger, Exaudi Deus deprecationem meam, EYBDt-4RjBQ.mid
# Chaminade, Cécile, Ritournelle, Op.83, WwzgwfZXkUU.mid
# Bortkiewicz, Sergei, Ein Roman, Op.35, vyJeeeoD1dI.mid
# Scarlatti, Domenico, Keyboard Sonata in C major, K.95, wGiY1clQjos.mid
# Villa-Lobos, Heitor, Petizada, W048, _Iuv0UkoBn4.mid
# Zaranek, Stefaniya, 5 Miniatures, Op.4, WjgplHonQ58.mid
# Lemoine, Henry, Impromptu sur des Motifs de Matilde de Sabran, CI_eOziu6KU.mid
# Heller, Stephen, Ländler and Walzer, Op.97, 2NU1B_95_1Q.mid
# Zarzycki, Aleksander, 2 Mazourkas, Op.20, q8MvlBz-bfE.mid
# Newton, P. W., Day Dreams, 2QwrS1GYldI.mid
# Philipp, Isidor, Pastels, Op.24, UngbyZZvcOQ.mid
# Torrent, Claude, Romance, Op.30, j3jvA7PUHT4.mid
# Gussakovsky, Apollon, Albumblatt, 4_0brRVtbEs.mid
# Henselt, Adolf von, Valse mélancolique, Op.36, cCLVUDMEuuk.mid
# Villar, Rogelio, Serenata andaluza, MUj_t8Pvf78.mid
# Bastl, Josef, Sonatina, Op.1, yIya_LgxZLk.mid
# Taneyev, Sergey, Lullaby, wcWhoZOaddA.mid
# Bial, Rudolf, Marie Polka, mRHcCqUkrPA.mid
# Gutmann, Adolf, 2 Mazurkas, Op.9, wrFYuHMuW7o.mid
# Bantock, Granville, Sapphic Poem, 7k5mGEwcoRw.mid
# Bach, Johann Sebastian, Sinfonia in F major, BWV 794, iE5aRQ87fSA.mid
# Del Valle de Paz, Edgardo, 2 Pezzi, Op.26, pMScaIu_I8g.mid
# Salomon, Hector, Clair de lune, b0zE3Rb4pAM.mid
# Elsner, Józef, Siedm razy jeden, wjikLTgUzow.mid
# Severo, Marcello, Piano Sonata No.3, Op.20, oDwpyvS9-lU.mid
# Teilman, Christian, Improvistion ved harpen, Op.116, upJW4ms18cQ.mid
# Nepomuceno, Alberto, Cloches de Noël, SN1.24, 43_3OS0mNsQ.mid
# Rimsky-Korsakov, Nikolay, Allegretto in C major, wRBzNcJWOho.mid
# Lyatoshinsky, Boris, Reflections, Op.16, oI2cI9xH0zI.mid
# Pezold, Christian, Minuet in G minor, BWV Anh.115, llZxwf8Dq4w.mid
# Cras, Jean, Poèmes Intimes, bUVAJoTkKwI.mid
# Chavagnat, Edouard, Étoile du matin, Op.201, nJUGde_RT_k.mid
# Goldenweiser, Aleksandr, Sonata-Fantasie, Op.37, B3pBvzQQMeY.mid
# Raff, Joachim, Am Giessbach, Op.88, vcMFloA4fHQ.mid
# Scarlatti, Domenico, Keyboard Sonata in A major, K.320, tXoW-WMSYow.mid
# Bendel, Franz, Improvisation on Walther's Preislied, u11_Pvzd5Nk.mid
# Scarlatti, Domenico, Keyboard Sonata in D major, K.160, ViHMmQDAkPQ.mid
# Costa Nogueras, Vicente, Humoresque, f86o9hbBNlU.mid
# Stief, Holger, Lost, JmbxC44_1jc.mid
# Shcherbachyov, Nikolay, Fantaisies-Etudes, Op.26, V-4OHZhh_Mk.mid
# Resinarius, Balthasar, Ach Gott vom Himmel sieh darein, TpK3MSud6fk.mid
# Hoschna, Karl L., Bright Eyes, FHJchIYZTwk.mid
# Wolf, Hugo, Aus der Kinderzeit, AVEn1ciFjNQ.mid
# Saint-Saëns, Camille, Menuet, dhT4AUuZoy0.mid
# Szymanowski, Karol, 4 Polish Dances, SAUoTijoNy0.mid
# Nazareth, Ernesto, Turbilhão de beijos, 3-PkETYt0uk.mid
# Stanchinsky, Aleksey, Variations, w0MsxuhZFHI.mid
# Simpson, Daniel Léo, Kleine Klavierstücke No.7 in G major, tOm5X9clsco.mid
# Schubert, Franz, Sonata for Piano Duet, D.812, Uml2lokoxbk.mid
# Brandeis, Frederick, 6 Piano Pieces, Op.57, eH7NF3lG1eg.mid
# Haydn, Joseph, Keyboard Sonata in D major, Hob.XVI:33, 1OD6WWNv5kg.mid
# Mayer, Charles, Valse-Etude, Op.83, ZfJ6D9PGOaA.mid
# Pryor, Arthur, Razzazza Mazzazza, Hw_0m8p-th0.mid
# Poulenc, Francis, 8 Nocturnes, FP 56, pDZxm7UQoYA.mid
# Beethoven, Ludwig van, 12 German Dances, WoO 13, N0nU0NPS-7c.mid
# Melartin, Erkki, Pienoiskuvia III, Op.53, F1gqWbUf5M4.mid
# Szopowicz, Henryk, 3 Mazurkas, Op.5, JF6j6I7tsaM.mid
# Toch, Ernst, 10 Mittelstufen-Etüden, Op.57, Oenw2jBQkMI.mid
# Larregla, Joaquín, Meditación, CG9F-2JlFss.mid
# Smetana, Bedřich, Czech Dances II, JB 1:114, 1XGY5HWqyCI.mid
# Bach, Johann Sebastian, Partita in G major, BWV 829, aecenXn3obw.mid
# Itazu, Shoryu, Eternal Peace Bell, fZn7ppcNmkc.mid
# Mason, William, Ballade No.1, Op.12, KoY5XWvk5C4.mid
# Giuliani, Mauro, 12 Waltzes, Op.90, REuyhBlr7mY.mid
# ...
# Gershwin, George, The Man I Love, dfJMQCQ91K4.mid
# Beach, Amy Marcy, Children's Album, Op.36, op8BXBAhShs.mid
# Schulhoff, Julius, 3 Nocturnes, Op.2, nEG2Y2fi27w.mid
# Stanchinsky, Aleksey, Prelude in Lydian Mode, b5fvk5wR-xM.mid
# Wenzel, Hermann, Souvenir, Op.15, p6zjxODIkmk.mid
# Teilman, Christian, När Trädens Blad de Falla, Jkr3eh58j-I.mid
# Parera, Blas, Himno nacional argentino, iydqxK-0Hos.mid
# Scriabin, Aleksandr, Poème-Nocturne, Op.61, nSqQ-B1EmpU.mid
# Fauré, Gabriel, 9 Préludes, Op.103, k4hihOHGjWY.mid
# Souto, Eduardo, Pelo Brasil, TqQcQ_OW2RM.mid
# Grünfeld, Alfred, Pizzicati aus Leo Delibes Ballett 'Sylvia', Op.60, wOcRLCmKyT8.mid
# Wagner, Richard, Ankunft bei den schwarzen Schwänen, WWV 95, 83pIdDPBQg4.mid
# Dvořák, Antonín, Waltzes, Op.54, JDDnoWomoYM.mid
# Voříšek, Jan Václav, 12 Rhapsodies, Op.1, _X_opiv7Hy8.mid
# Carlier, Xaver, Valse Caprice, j5gB3CFvU70.mid
# Pfeiffer, Gregory Carl, Edges, zPVUujFyMtM.mid
# Zaremba, Sigizmund, Nocturne, Op.55, NONg06Pf0v8.mid
# David, Adolphe, Petite valse alsacienne, g0Hc1lSJFaE.mid
# Liszt, Franz, Hungarian Rhapsody No.13, S.244_13, 5qrH8_8OFqg.mid
# Séverac, Déodat de, Le chant de la terre, w_gszEtzi7A.mid
# Carreño, Teresa, Gottschalk Waltz, 648IqZ4YW34.mid
# Joplin, Scott, A Breeze from Alabama, nXe43xnOEf4.mid
# Bach, Carl Philipp Emanuel, Keyboard Sonata in D major, H.177, OXbo42cAi_U.mid
# Bohm, Carl, Blumengruss, Op.284, wmNVshhdCus.mid
# Chopin, Frédéric, Rondo in E-flat major, Op.16, CxSEdBKcQYE.mid
# Vītols, Jāzeps, Au Clair de la Lune, Op.41, jzxsS22CaFw.mid
# Puccini, Giacomo, Morire?, SC 89, iCouVQkGHps.mid
# Huber, Hans, Waltzes for Piano Four-Hands, Op.59, WQwkcstSmCc.mid
# Mathé, Edouard, Miniature-Valse, aszw6FOIJFE.mid
# Beach, Amy Marcy, 2 Piano Pieces, Op.102, kTBbDsx5l64.mid
# Dussek, Jan Ladislav, Piano Sonata No.23, Op.47 No.2, rDCmHkmVmjo.mid
# Botsford, George, Black and White Rag, kffg-uIopO4.mid
# Comellas, José, Vienne, Op.4, 6raRXPeAMsc.mid
# Karlsen, HanS, Ještě dýšu, SsF8YuzsXQo.mid
# Teilman, Christian, Festmarsch, oljtzj1YMHU.mid
# Czerny, Carl, 24 Airs populaires en rondeaux, Op.609, PVwm5bHp6E0.mid
# Rossi, Michelangelo, Andantino ed Allegro, ANY7dA4frp4.mid
# Moeran, Ernest John, Toccata, MTW2F6_SZMY.mid
# Scriabin, Aleksandr, Nocturne, dKC4fUNfe8g.mid
# Bouman, Antonius Johannes, 3 Morceaux, Op.10, xMNx-LCZbnQ.mid
# Dedieu-Péters, Paul, Antonia, MchpLAzhwY8.mid
# Gutmann, Adolf, 2 Nocturnes, Op.8, dgNq_WHg52U.mid
# Schubert, Franz, 6 German Dances, D.820, NabtIIRnM3Q.mid
# Knox, William Robert, Twilight, Op.12, qNe6URuC8D0.mid
# Kummer, Kaspar, Variations, Op.62, fUsPQC5ftmA.mid
# Arcas, Julián, La Saltarina, zynxW0nWNBk.mid
# Boumard, Jean, Mazurka, Op.7, JUHmr7ZCSoI.mid
# Alkan, Charles-Valentin, Petit conte, pJwOucXTls0.mid
# Sveinbjörnsson, Sveinbjörn, Idyl, K7ZCHSCriLI.mid
# Lavignac, Albert, Berceuse, Op.18, 66PKn1JnLy4.mid
# Satie, Erik, Chanson Hongroise, XEIjqkBPw-c.mid
# Kleber, Henry, The Elena Polka, hcLBLuizvmY.mid
# Bellenot, Philippe, Sérénade, nr-4CH7yhxQ.mid
# Wilson, Grenville Dean, Piano Sonatina, Op.144, JYLhGxsK9xk.mid
# Gomes, Carlos, Grande valsa de bravura, NnJO_ZDHln8.mid
# Morales, Cristóbal de, Qui consolabatur me, Fzk5L2sZryw.mid
# Granados, Enrique, Moresque y Canción Arabe, uWD6AssYzZE.mid
# Goetz, Hermann, Sonata for Piano (Four Hands), Op.17, 1EmU3c0fKOk.mid
# Reinecke, Carl, Variationen über eine Sarabande von J.S. Bach, Op.24, _T58-uZOxwo.mid
# Glinka, Mikhail, Variations on Alyabyev's Romance 'The Nightingale', w8dl6Tcqz_A.mid
# Meyer-Helmund, Erik, 3 Lieder, Op.20, Nu0isYm7ipo.mid
# Guéroult, Auguste, Chansons d'Alfred de Musset, Op.3, sFgXUBPF3Nk.mid
# Marando, A., Nocturne No.2, Op.12, UmkW7JZibxg.mid
# Reinhold, Hugo, Acrostichon, Op.54, vFAy8QOWHa0.mid
# Bach, Johann Sebastian, Invention in D minor, BWV 775, 3JVYh1ZX78c.mid
# Czerny, Carl, Krönungsmarsch, Op.101, mGsuDxie7ic.mid
# Kühmstedt, Friedrich, Organ Sonata No.2, Op.40, a2ZQrAXw0PQ.mid
# Kempinski, Leo A., Burlesque on Verdi's 'March', hzOBAD1tNyU.mid
# Scharwenka, Philipp, Hochzeitsmusik, Op.23, 1t0hlc5_KE4.mid
# Scharwenka, Xaver, Polonaise, Op.7, a2MIo0hlQxM.mid
# Violette, Andrew, Intermezzo, iMtiZpf9YB4.mid
# Mozart, Wolfgang Amadeus, La Tartine de beurre, XIbgGcWqBy4.mid
# Bovy-Lysberg, Charles Samuel, Idylle, Op.62, ytDY-fJtHDA.mid
# Eiges, Konstantin, 4 Morceaux, Op.14, 9YZMs6mjO4s.mid
# Bonnal, Ermend, Menuet triste, q5QPngAY640.mid
# Harding, Alfred Harry, 2 Egyptian Dances, XKlTae3thlw.mid
# Scarlatti, Domenico, Keyboard Sonata in B-flat minor, K.131, UAJk0RkwR3k.mid
# Tchaikovsky, Pyotr, 2 Pieces, Op.10, AKGED6tG9M8.mid
# Harrington, Jeffrey Michael, Piano Prelude No.16, wSlAWLvgM8o.mid
# Lack, Théodore, Bataille de Fleurs, Op.101, NcUSHr8IDYY.mid
# Johnson, Charles Leslie, Apple Jack, Ua__cXC85BE.mid
# Alain, Albert, Espagnolerie, ts4pTlWdmMg.mid
# Poulenc, Francis, Suite pour piano, FP 19, zRvDH9OTyXY.mid
# Turina, Joaquín, Partita in C major, Op.57, 7iN7TfvWdnY.mid
# Teilman, Christian, Menuet, Op.52, VJ3jxr5E9J4.mid
# Aramaki, Michio, 32*3, Op.32, CqN0r8NOou0.mid
# Krzyżanowski, Ignacy, Impromptu, Op.52, BN1D63HHab0.mid
# Gouvy, Louis Théodore, Scherzo et Aubade, Op.77, OtDrhh77yyw.mid
# Rowley, Alec, Polly Perkins, 30CbwPqHtx0.mid
# Haydn, Joseph, Partita in D major, Hob.XVI:14, EyG3Uye8t5Q.mid
# Scarlatti, Domenico, Keyboard Sonata in F major, K.194, t9SS_PQq2Y0.mid
# Gonzaga, Chiquinha, Bijou, f-aJ7_IacwY.mid
# Caplet, André, Un tas de petites choses, xE4hyAkOSgc.mid
# Sibelius, Jean, 10 Bagatelles, Op.34, cr0pp4GMVVU.mid
# Liszt, Franz, Paraphrase de concert sur Rigoletto, S.434, mu_sVBOmE2A.mid
# Hennessy, Swan, La fille aux cheveux de lin, PzZaHUlYpSw.mid
# Scarlatti, Domenico, Keyboard Sonata in E minor, K.232, 1Mg3NoOAFBU.mid
# Astort Ribas, Pedro, Amoureusement, Sr_p2YphcMI.mid
# Widor, Charles-Marie, 6 Duos, Op.6, aBRB96cPa-c.mid
# Hindemith, Paul, Horn Sonata, IMZ4PdJThe8.mid
# Kalkbrenner, Friedrich Wilhelm, Introduction et polonaise brillante, Op.141, x9Op856c8wU.mid
# Bartók, Béla, Suite for Piano, Op.14, 46Hd1p92uco.mid
# Leszczewski, Wladislaw, Mazurka No.1, Op.1, Gwm0iVPckSM.mid
# Henselt, Adolf von, Impromptu No.3, Op.34, w37Sw_I9Mvk.mid
# Casella, Alfredo, A Notte Alta, Op.30, Whn5gEmLl2c.mid
# Peuerl, Paul, Intrada, -U5CvDRS8M4.mid
# Gedike, Aleksandr, 60 Easy Piano Pieces, Op.36, TKGHLQn8_54.mid
# Grunn, Homer, Indian Lament, N7oAlPurP60.mid
# Lacombe, Louis, Galop de concert, Op.13, l48uJnv_zeg.mid
# Tausig, Carl, Valse-Caprice No.5, 6bDR8ejJBog.mid
# Ketterer, Eugène, Mazurka de salon, Op.2, eSA5n9MlsNA.mid
# Steane, Bruce, Come See the Place Where Jesus Lay, C6ydHyO7dzY.mid
# Baumfelder, Friedrich, Erinnerung, Op.159, nRPU28VlIWw.mid
# Liszt, Franz, Fantasie über Themen aus Mozarts Figaro und Don Giovanni, S.697, ZVevtrU8Oik.mid
# Juon, Paul, Den Kindern zum Lauschen, Op.38, CBmwntURkvw.mid
# Chopin, Frédéric, Variations sur un air national allemand, B.14, wg_2Fz1gB1s.mid
# Rzewski, Frederic, Flowers 1, ai5Xh4yLQ5k.mid
# Johnson, Charles Leslie, Under the Southern Moon, NTl1KIZEZrc.mid
# Gouvy, Louis Théodore, Lilli Bulléro, Op.62, KRs483iyy6k.mid
# Besset, Julian Raoul, By the Fireside, wqJuSYqSG38.mid
# Moszkowski, Moritz, 12 Etudes for the Left Hand, Op.92, RzTX-4IEnes.mid
# Marschner, Heinrich, Introduction et Rondeau brillant, Op.74, TaAxHUwzVXw.mid
# MacDowell, Edward, 10 Woodland Sketches, Op.51, X-IxADlkApc.mid
# Chopin, Frédéric, Barcarolle, Op.60, UU21X-wmD0Q.mid
# Alba, Antonio, Pensando en ti, Op.9, MaCQttuzirY.mid
# Kuhlau, Friedrich, 6 Scottish Dances, WoO 218, 3VZIA0oGk8Y.mid
# Wachs, Paul, Valse idéale, 2j8ax92E558.mid
# Arensky, Anton, 6 Caprices, Op.43, QR2RODBRAU0.mid
# Carbajo, Víctor, Pandemonium Sonatina, CMJx70CNVZ8.mid
# Schubert, Franz, 4 Polonaises, D.599, gwOp5lEOknY.mid
# Skoumal, Adam, Etudes for Piano, YNge21PTFvI.mid
# Gurlitt, Cornelius, 6 Bagatelles, Op.224, 3PpZB7TcVsM.mid
# Turina, Joaquín, Desde mi terraza, Op.104, iwV9CFBfnoc.mid
# Diabelli, Anton, Alla Turca, xstjmi9r0W4.mid
# Kinkel, Charles, Mountain Belle Schottische, 5OzRZFcBJa8.mid
# David, Félicien, Romance sans paroles, zVR4Am-FVf8.mid
# Lack, Théodore, Études artistiques, Op.91, KmDjHHcA41g.mid
# Michałowski, Aleksander, 2 Bagatelles, Op.35, LVZYXuvzfpE.mid
# Goetz, Hermann, 6 Genrebilder, Op.13, UjaizsTyt3s.mid
# Methfessel, Albert Gottlieb, Weihnachtsabend, WO1F8VxcxZo.mid
# Praeger, Ferdinand, Gavotte in E-flat major, 8seMTGlCp4I.mid
# Moszkowski, Moritz, 6 Morceaux, Op.31, ObABnSkn2g4.mid
# Ries, Ferdinand, Introduction et rondo, Op.113 No.2, m_vk34DiZBA.mid
# Kozeluch, Leopold, Piano Sonata, Op.38 No.2, I2gY1gO1KV8.mid
# Alexandra, Liana, Sonata for 6 Horns, aOzAb9_oFjw.mid
# Oswald, Henrique, Album, Op.33, Tz2FBvYcw24.mid
# Heller, Stephen, 3 Nocturnes, Op.91, 0oldk_zokco.mid
# Pugno, Raoul, Impromptu-valse, haOI2AfYGBs.mid
# Mozart, Wolfgang Amadeus, Minuet in C major, K.1f, krCV6mcKU-w.mid
# Joplin, Scott, Please Say You Will, kJcYVm1_Rlo.mid
# Brahms, Johannes, 2 Gigues, WoO 4, NgyLwzf9ZeQ.mid
# Fauré, Gabriel, Barcarolle No.6, Op.70, vWGeoLN_0bI.mid
# Smith, Boyton, Tarantella, gegtr8MdvXk.mid
# Franchomme, Auguste, Fantaisie sur des motifs de la 'Semiramide', Op.31, fULiZGNsBxM.mid
# Strauss Jr., Johann, Bürgersinn Walzer, Op.295, xbY3igv1Hgk.mid
# Santos Carrión, Julián, Iberiana, vHIbQKVO6z8.mid
# Scharwenka, Xaver, 2 Polish Dances, Op.34, ROvdXpOi9IM.mid
# Feininger, Lyonel, Fugue in E-flat minor, gXnRl6VHzjI.mid
# Vecchi, Orazio, Fummo felici un tempo, TOBnTuAGmuE.mid
# Nacci, Andrea Antonello, Improvviso, ZhU1TOUcI1U.mid
# Myaskovsky, Nikolay, Song and Rhapsody, Op.58, G6gaYZp7gtc.mid
# Čiurlionis, Mikalojus Konstantinas, Fughetta in D minor, vblDk6Ax3Xw.mid
# Beach, Amy Marcy, Variations on Balkan Themes, Op.60, U2xTaHNWlV0.mid
# Czerny, Carl, Andante in C major, s5VnW5ACfbk.mid
# Niewiadomski, Stanisław, 2 Mazureks, Op.26, S50IsRD2lIM.mid
# Sixt, Johann Abraham, Keyboard Sonata in A major, 9ag2q62BNrA.mid
# Scarlatti, Domenico, Keyboard Sonata in C minor, K.126, z9ws4Rcgrxs.mid
# Ravel, Maurice, Miroirs, 0VdZR3deNdI.mid
# Mozart, Wolfgang Amadeus, 2 Fugues in E-flat major, K.deest, h-ZjmTxJBq4.mid
# Drew, Harry, Minuet, cABolO-MTQA.mid
# Margis, Alfred, Valse Bleue, zbyehawUON4.mid
# Scarlatti, Domenico, Keyboard Sonata in E-flat major, K.508, ZbzlNz7pdkk.mid
# Clarke, Jeremiah, King's March, CUTnwhr4s9g.mid
# Calvi, Carlo, Aria di Fiorenza &amp; Sua Corrente, KAUi2bS9YiI.mid
# Moszkowski, Moritz, 15 Etudes de Virtuosité, Op.72, wu1986U6Ckc.mid
# Bach, Carl Philipp Emanuel, Solfeggio in A major, H.222, DZ9SFyeV1Dk.mid
# Tena Manrique, Abraham, Confession, Op.31, pRriq7_MvaI.mid
# Martinez, Marianne, Piano Sonata in A major, wiPkpgWsUXM.mid
# Petering, Mark, Prelude to Kakadu Rain, ajwSnvneous.mid
# Joshi, Rohan, Qui belles amours a (Josquin Desprez), Gxobkk4qvko.mid
# Zarzycki, Aleksander, Mazurka No.2, Op.39, apyu-Qtpsbg.mid
# Haas, Joseph, Schwänke und Idyllen, Op.55, cOIfpRWf2ZE.mid
# Satie, Erik, Prélude en tapisserie, c8a1Fc01kd8.mid
# Jacobi, Viktor, Szibill, dXJgMfsNy1E.mid
# Scriabin, Aleksandr, 5 Preludes, Op.74, MApCm3UO6nQ.mid
# Beethoven, Ludwig van, 32 Variations in C minor, WoO 80, U-qdxKyR9PU.mid
# Marmontel, Antoine François, Toccatina, Op.111, 2E2jdd9oOQo.mid
# Brahms, Johannes, Piano Sonata No.2, Op.2, RhZqUE63B9g.mid
# Pearson, Kevin, Preludium 1, WrCD7rylAno.mid
# Henri, Petrini, Etude de la main gauche, Op.9, oVDVaPBBNzM.mid
# Urban, Julius, 2 Lieder ohne Worte, y6P5zHQP6Z0.mid
# Smith, Sydney, La danza, Tarantella napolitana de Rossini, Op.104, HBKsmR023BI.mid
# Lahme, Christoph, Wedding March on 'Praise to the Lord the Almighty', PDaDr3Ft8QA.mid
# Liszt, Franz, Ballade No.1, S.170, fjOJjut6-x4.mid
# Smith, Sydney, Lily of the Valley, Op.14, SX9Zp6tgJK4.mid
# Liszt, Franz, Variationen über das Motiv von Bach, S.180, OP2CeT2w9HQ.mid
# Carbajo, Víctor, Plaster Hearts, 6PZ46QA9KnI.mid
# Smith, Sydney, Grande fantaisie on 'Les Huguenots', Op.44, dLYkuvtlNAw.mid
# Schumann, Robert, 4 Marches, Op.76, G1w7DSpw4I8.mid
# Kozeluch, Leopold, A Favorite Rondo for the Piano, l9Ph5cH2FKA.mid
# Niewiadomski, Stanisław, 4 Charakterstücke, Op.28, PNGaoy0dVXA.mid
# Martinů, Bohuslav, Film en miniature, H.148, iIOVuGK1JCM.mid
# Alba, Antonio, Pitios, PlRD1p-349c.mid
# Mattiozzi, Rodolfo, Valse poétique, 55s81R6WRws.mid
# Scarlatti, Domenico, Keyboard Sonata in G major, K.55, dhD2BTYZ58k.mid
# Szymanowski, Karol, Piano Sonata No.3, Op.36, xFv5B9qdglQ.mid
# Pfeiffer, Georges Jean, La gitanilla, Op.91, OZ__bFdJ9cU.mid
# Saint-Saëns, Camille, Improvisation sur la Beethoven-Cantate, -afx16u0VTY.mid
# Benavente, Manuel, Scherzo, Op.27, HePKuMDN2AU.mid
# Mayerl, Billy Joseph, Canaries' Serenade, zbgB-nhimvk.mid
# Villa-Lobos, Heitor, Rudepoema, W184, 310, cm3qZ8xiePs.mid
# Bellando, Domenico, Favoletta, YbMfZ12kkTw.mid
# Beatty, Stephen W., Duet for Cimbasso and Tuba, Op.1491, au8Gf7OOV9E.mid
# Simpson, Daniel Léo, Prelude and Fugue No.7 in D major, oZJwO_t3Dv0.mid
# Handel, George Frideric, Minuet in F major, HWV 515, b97QFpkELuQ.mid
# Snuggs, Colin Peter, Piano Sonata No.5 in G major, LM-P6B7RWrE.mid
# Mikuli, Carl, Mazurka, Op.4, 5_8CVCzJM24.mid
# Saral, Ali Riza, Prelude and Fugue for Piano, Xcl8QkkWNQo.mid
# Graupner, Christoph, Partita in G major, GWV 142, cSylz6n88lA.mid
# Suk, Josef, 8 Piano Pieces, Op.12, fu-38qVA7a4.mid
# Bohm, Carl, Zitherständchen, Op.113, fxl_WLVxNG8.mid
# Hoffmeister, Franz Anton, Keyboard Sonata in A major, WeiH 37, fWphrOutbEo.mid
# Simpson, Daniel Léo, Invention No.8 in G major, ZYS8gbbT_Dg.mid
# Mullen, Alfred Frederic, Twelfth Night, iIcgH5Hs09Y.mid
# Backer-Grøndahl, Agathe, 3 Klavierstücke, Op.25, J6-Fjpu-f8k.mid
# Dukas, Paul, Piano Sonata, G5Q7r7WhFxI.mid
# Nazareth, Ernesto, Recordações do passado, qjcWTjvxvg4.mid
# Scarlatti, Domenico, Keyboard Sonata in D major, K.298, 9GRXZyBS5Dc.mid
# Johnson, Charles Leslie, Blue Goose Rag, HbXkJZH9cc4.mid
# Turovsky-Savchuk, Roman, Tombeau sur la mort de mon maître, 8xqGNJc33p0.mid
# Rebikov, Vladimir, Snow White, Op.39, htARakxsGGg.mid
# Hofmann, Heinrich, Italienische Liebesnovelle, Op.19, BDyi9nopqvQ.mid
# Shirley, Nathan, Toccata, kd2rrTURT4o.mid
# Scarlatti, Domenico, Keyboard Sonata in G major, K.372, pKkZn4OXOks.mid
# Rebikov, Vladimir, Les étrennes de Noël, cJ34vjYfJY0.mid
# Arensky, Anton, 12 Pieces, Op.66, 1gHUrBfosC0.mid
# Scarlatti, Domenico, Keyboard Sonata in A major, K.499, GMUmpdPDCVA.mid
# Bennett, William Sterndale, Piano Sonata, Op.13, ZmyDANVxhOc.mid
# Kunz, Konrad Max, 200 Short Two-Part Canons, Op.14, U2uqJvwjnsA.mid
# St. George Tucker, Tui, Blue Mountain, VyeAkfL8fmM.mid
# Frysinger, Frank, Chant sans paroles, 3Z6KfAA3QWg.mid
# Weckerlin, Jean-Baptiste, Lison dormait, lXp4TWztdMQ.mid
# Rowley, Alec, Cotswold Love, nA6ViptqUv4.mid
# Handel, George Frideric, Suite in G minor, HWV 439, eew-90TtWfo.mid
# Van Alstyne, Egbert, Seminole, HgNoqmtDdHw.mid
# Scarlatti, Domenico, Keyboard Sonata in G major, K.470, 3vWC6j9tsDE.mid
# Bouillet, Jean-Marc, Impromptu No.1 in A-flat major, Fus_YMB2k4k.mid
# Victoria, Tomás Luis de, Doctor egregie Paule, u5mpMzu0Vvc.mid
# Donizetti, Gaetano, Marcia lugubre, A 563, hgVUCQ5HsHY.mid
# Wilhelmj, August, All'Ungherese, UlIeFLH223E.mid
# Nollet, Eugène, Marche des Houris, Op.66, SWpao854j50.mid
# Rockstro, William Smith, Voices from the Hill-Side, mhJd5G26VLU.mid
# Pierné, Gabriel, Valse-Impromptu, Op.27, jGk9CvEZU-o.mid
# Lenepveu, Charles-Ferdinand, Caprice, ef_EeaRyHMQ.mid
# Kopylov, Aleksandr, Étude, Op.9, SEM_Kxgb4u4.mid
# Mozart, Wolfgang Amadeus, Allegro in B-flat major, K.3, Fa3kYVF62ak.mid
# Michałowski, Aleksander, Menuet, Op.15, m1vei8HrgNU.mid
# Mozart, Wolfgang Amadeus, Piano Sonata No.17 in B-flat major, K.570, kVwEkgQ3dPs.mid
# Ferrari, Carlotta, Portatori di sogni, k2R_uSJEydE.mid
# Ropartz, Guy, Dans l'Ombre de la Montagne, -ARR5eUQJ9s.mid
# Scarlatti, Domenico, Keyboard Sonata in B-flat major, K.488, kiJv2KGt6I8.mid
# Elteart, Vivien Mertz, Pièce No.2 pour 2 éventuels pianos, UGPAs6UNvKU.mid
# Döhler, Theodor, Nocturne No.1, Op.24, pvYqV_P_PYY.mid
# Burgmüller, Friedrich, Valse hongroise sur 'Néméa', XoQqn4AF868.mid
# Godard, Benjamin, Valse No.7, Op.101, fJFEqVaoPFI.mid
# Carr, Benjamin, Fantasia on the Air Gramachree, R_3p2aF_13I.mid
# Liszt, Franz, Hungarian Rhapsody No.7, S.244_7, iIQ_SfPug0s.mid
# Pfeifer, Johann, Verlorenes Glück, Op.1 No.2, PAn8SUjEK8M.mid
# Praeger, Ferdinand, Piano Sonata No.28 in C major, iPeWZ0TifAM.mid
